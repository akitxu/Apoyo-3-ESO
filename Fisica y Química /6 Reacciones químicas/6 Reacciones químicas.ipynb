# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %% [markdown]
# # 6 Reacciones Químicas.

# %% [markdown]
# ## Los cambios químicos

# %% [markdown]
# ## ¿Qué sucede con los elementos químicos en las reacciones?.

# %% [markdown]
# ## ¿Se conserva la masa en las reacciones químicas?

# %% [markdown]
# ## ¿Qué suce con las moléculas y los átomos?.

# %% [markdown]
# ## Representación e interpretación de las reacciones químicas.

# %% [markdown]
# ## ¿Cómo se ajusta una reacción química?.

# %% [markdown]
# ##

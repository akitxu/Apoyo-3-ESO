-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>¿Qué diferencia de potencial hay que aplicar a un reóstato de 30 ohmios para que circulen a través de él 5 amperios?. (Sol: 150V)</a></span></li><li><span><a href="#En-el-circuito-de-la-figura,-calcular-las-resistencias-A-y-B-y-la-diferencia-de-potencial-aplicada.-(Sol:-4-$\Omega$,-6-$\Omega$-y-65V)." data-toc-modified-id="En-el-circuito-de-la-figura,-calcular-las-resistencias-A-y-B-y-la-diferencia-de-potencial-aplicada.-(Sol:-4-$\Omega$,-6-$\Omega$-y-65V).-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>En el circuito de la figura, calcular las resistencias A y B y la diferencia de potencial aplicada. (Sol: 4 $\Omega$, 6 $\Omega$ y 65V).</a></span></li><li><span><a href="#Un-motor-está-construido-para-trabajar-con-una-corriente-de-3.5A-a-una-diferencia-de-potencial-de-115V.-Este-motor-se-instalaen-una-red-en-la-que-la-tensión-es-de-125V.-Calcular-el-valor-de-la-resistencia-que-hay-que-montar-en-serie-con-el-motor-para-conservar-el-valor-previsto-de-la-corriente.-(Sol:-2,85-$\Omega$)" data-toc-modified-id="Un-motor-está-construido-para-trabajar-con-una-corriente-de-3.5A-a-una-diferencia-de-potencial-de-115V.-Este-motor-se-instalaen-una-red-en-la-que-la-tensión-es-de-125V.-Calcular-el-valor-de-la-resistencia-que-hay-que-montar-en-serie-con-el-motor-para-conservar-el-valor-previsto-de-la-corriente.-(Sol:-2,85-$\Omega$)-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>Un motor está construido para trabajar con una corriente de 3.5A a una diferencia de potencial de 115V. Este motor se instalaen una red en la que la tensión es de 125V. Calcular el valor de la resistencia que hay que montar en serie con el motor para conservar el valor previsto de la corriente. (Sol: 2,85 $\Omega$)</a></span></li><li><span><a href="#Un-circuito-está-formado-por-tres-resistencias-en-serie.-Cada-resistencia-tiene-uin-valor-doble-que-la-anterior.-Al-aplicar-al-circuito-una-d.d.p.-(diferencia-de-potencial)-de-100V-circula-una-corriente-de-2A.Calcular-el-valor-de-cada-resistencia.-(Sol:-7,14--,-14,28--,-28,56)" data-toc-modified-id="Un-circuito-está-formado-por-tres-resistencias-en-serie.-Cada-resistencia-tiene-uin-valor-doble-que-la-anterior.-Al-aplicar-al-circuito-una-d.d.p.-(diferencia-de-potencial)-de-100V-circula-una-corriente-de-2A.Calcular-el-valor-de-cada-resistencia.-(Sol:-7,14--,-14,28--,-28,56)-1.9"><span class="toc-item-num">1.9&nbsp;&nbsp;</span>Un circuito está formado por tres resistencias en serie. Cada resistencia tiene uin valor doble que la anterior. Al aplicar al circuito una d.d.p. (diferencia de potencial) de 100V circula una corriente de 2A.Calcular el valor de cada resistencia. (Sol: 7,14  , 14,28  , 28,56)</a></span></li><li><span><a href="#Hallar-la-resistencia-de-dos-conductores-de-2-y-8-ohmios-respectivamente-que-están-montados-en-paralelo.-(Sol:-1,6-$\Omega$)" data-toc-modified-id="Hallar-la-resistencia-de-dos-conductores-de-2-y-8-ohmios-respectivamente-que-están-montados-en-paralelo.-(Sol:-1,6-$\Omega$)-1.10"><span class="toc-item-num">1.10&nbsp;&nbsp;</span>Hallar la resistencia de dos conductores de 2 y 8 ohmios respectivamente que están montados en paralelo. (Sol: 1,6 $\Omega$)</a></span></li><li><span><a href="#Hallar-la-resistencia-de-tres-conductores-de-20,30-y-40-ohmios-respectivamente-que-están-montados-en-paralelo.--(Sol:-9,23-$\Omega$" data-toc-modified-id="Hallar-la-resistencia-de-tres-conductores-de-20,30-y-40-ohmios-respectivamente-que-están-montados-en-paralelo.--(Sol:-9,23-$\Omega$-1.11"><span class="toc-item-num">1.11&nbsp;&nbsp;</span>Hallar la resistencia de tres conductores de 20,30 y 40 ohmios respectivamente que están montados en paralelo.  (Sol: 9,23 $\Omega$</a></span></li><li><span><a href="#Cinco-resistencias-identicas-se-montan-en-paralelo-sobre-una-línea-de-100V.-Calcular-la-corriente-que-pasa-por-el-grupo-sabiendo-que-la-resistencia-de-cada-lámpara-vale-400-ohmios.-(Sol:-1,25A)" data-toc-modified-id="Cinco-resistencias-identicas-se-montan-en-paralelo-sobre-una-línea-de-100V.-Calcular-la-corriente-que-pasa-por-el-grupo-sabiendo-que-la-resistencia-de-cada-lámpara-vale-400-ohmios.-(Sol:-1,25A)-1.12"><span class="toc-item-num">1.12&nbsp;&nbsp;</span>Cinco resistencias identicas se montan en paralelo sobre una línea de 100V. Calcular la corriente que pasa por el grupo sabiendo que la resistencia de cada lámpara vale 400 ohmios. (Sol: 1,25A)</a></span></li><li><span><a href="#Calcularla-resistencia-reducida-del-circuito-que-indica-el-esquema.-(Sol:-2,25-$\Omega$)" data-toc-modified-id="Calcularla-resistencia-reducida-del-circuito-que-indica-el-esquema.-(Sol:-2,25-$\Omega$)-1.13"><span class="toc-item-num">1.13&nbsp;&nbsp;</span>Calcularla resistencia reducida del circuito que indica el esquema. (Sol: 2,25 $\Omega$)</a></span></li><li><span><a href="#CÁLCULO-DE-LA-RESISTIVIDAD.-Determinar-la-resistividad-de-un-conductor-que-tiene-4-Km-de-longitud,-16-mm2de-sección-y-una-resistencia-de-20-Ω.-(Sol:-0,08-$-\frac{\Omega-\cdot-mm²}{m}$)" data-toc-modified-id="CÁLCULO-DE-LA-RESISTIVIDAD.-Determinar-la-resistividad-de-un-conductor-que-tiene-4-Km-de-longitud,-16-mm2de-sección-y-una-resistencia-de-20-Ω.-(Sol:-0,08-$-\frac{\Omega-\cdot-mm²}{m}$)-1.14"><span class="toc-item-num">1.14&nbsp;&nbsp;</span>CÁLCULO DE LA RESISTIVIDAD. Determinar la resistividad de un conductor que tiene 4 Km de longitud, 16 mm2de sección y una resistencia de 20 Ω. (Sol: 0,08 $ \frac{\Omega \cdot mm²}{m}$)</a></span></li><li><span><a href="#CÁLCULO-DE-LA-LONGITUD-DE-UN-CONDUCTOR.-Calcular-la-longitud-de-un-hilo-de-ferro-niquel-de-2.6mm-de-diámetro-y-500Ωde-resistencia.-(Resistividad=-0.8-$-\frac{\Omega-\cdot-mm²}{m}$)-(Sol:-3318,3-m)" data-toc-modified-id="CÁLCULO-DE-LA-LONGITUD-DE-UN-CONDUCTOR.-Calcular-la-longitud-de-un-hilo-de-ferro-niquel-de-2.6mm-de-diámetro-y-500Ωde-resistencia.-(Resistividad=-0.8-$-\frac{\Omega-\cdot-mm²}{m}$)-(Sol:-3318,3-m)-1.15"><span class="toc-item-num">1.15&nbsp;&nbsp;</span
</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# [adaptado de wordpress.com](https://aliciadiazcobo.files.wordpress.com/2012/05/electricidad3c2baresueltos_formulari.pdf)

# %% [markdown]
# # FORMULAS MÁS USADAS EN ELECTRICIDAD.
#
# **FUERZA ELECTROMOTRIZ (**f.e.m.**)**: Es la fuerza necesaria para trasladarlos electrones desde el polo positivo y depositarlos en el polo negativo de un generador eléctrico. Su unidad es el **VOLTIO(V)**.
#
# **POTENCIAL ELÉCTRICO**: Se dice que un cuerpo cargado posee una energía o potencial. Su unidad es el **VOLTIO(V)**.
#
# **DIFERENCIA   DE   POTENCIAL   (d.d.p.)**:Es   la   diferencia   de   potencial eléctrico   entre   dos   cuerpos.   También   se   le llama **TENSIÓN o VOLTAJE**. Su unidad es el **VOLTIO(V)**.
#
# **RESISTENCIA ELÉCTRICA**: Es la oposición que ofrece un cuerpo al paso de la corriente eléctrica. Se representa por la letra **(R)** y su unidad es el **OHMIO(W)**.

# %% [markdown]
# ## Ley de Ohm
#
# **Intensidad es igual a la tensión partida por la resistencia**. Donde:
#
# * **I** es la intensidad en amperios **(A)**.
#
# * **V** es la tensión en voltios **(V)**.
# * **R** es la resistencia en **ohmios (Ω)**.
#
# * **I = Intensidad de corriente en Amperios (A)**.
#
# * **N = Número de electrones medidos enCulombios (C)**.
#
# * **t  =  Tiempo en segundos (s)**.
#
# $ 1A =  \frac{1C}{1s} \quad$ $1C =6’242 \cdot 10^{18} e^{-}$

# %% [markdown]
# ### Resistencia de un conductor
#
# La resistencia de un conductor es igual a la longitud partida por la sección Por su resistividad.Donde:
#
# * **R** es la resistencia en ohmios **(Ω)**
#
# * ** $\varrho$ la resistividad del material $ \frac{\Omega \cdot mm²}{m}$.
# * **L** es la longitud del conductor en metros **(m)**
#
# * **S** es la sección del conductor en milímetros cuadrados **$mm^2$**
#
# $$ R = \varrho \frac{L}{S}$$

# %% [markdown]
# ### Cálculo de la potencia.
#
# Las tres formulas básicas, para calcular la potencia de una resistencia son.
#
# $$ P = V \cdot I \qquad P = R \cdot I^2 \qquad P = \frac {V^2}{R}$$
#
# * **P** es la potencia en vatios **(W)** 1 watio = 1 voltio x 1 Amperio
#
# * **V** es la tensión en voltios **(V)**
#
# * **I** es la intensidad en amperios **(A)**
#
# * **R** es la resistencia en ohmios **(Ω)**

# %% [markdown]
# ### Potencia y energía
#
# Potencia es igual a la energía dividido por el tiempo. Si la unidad de potencia **(P)** es el watt  o **watio(W)**, la energía **(E)** se expresa en julios **(J)** y el tiempo **(t)** lo expresamos en segundos,
#
# 1 julio = 1 watio x 1 segundo   1 kilowatt = 1.000 watt y 1 hora = 3.600 segundos, por lo tanto
#
# $$1 Kilowatio-hora = 1 KWh = 1.000 watio \times 3.600 segundos = 3,6 x 10^6 julios$$

# %% [markdown]
# ## Hállese la resistencia de una estufa que consume 3 amperios a una tensión de 120 voltios. (Sol: 40 $\Omega $)

# %% [markdown]
# ##  ¿Qué diferencia de potencial hay que aplicar a un reóstato de 30 ohmios para que circulen a través de él 5 amperios? (Sol: 150V)

# %% [markdown]
# ##  En el circuito de la figura, calcular la **resistencia total**, la **intensidad que circula** y las **caidas de tensión producidas en cada resistencia.** (Sol: 10  $\Omega $, 12A y 120V)
#
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# Podemos observar que en los circuitos de resistencias en serie la intensidad que circula es la misma en todos los punto del circuito.Mientras que la tensión varía en cada resistencia, dependiendo del valor de cada unade ellas.

# %% [markdown]
# ## En el circuito de la figura, calcular la resistencia total y la resistencia X. La tensión en los extremos del sircuito es de 120V. Sol: 59$\Omega $ , 47 $\Omega $,
#
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# ##  ¿Qué diferencia de potencial hay que aplicar a un reóstato de 30 ohmios para que circulen a través de él 5 amperios?. (Sol: 150V)

# %% [markdown]
# ##  En el circuito de la figura, calcular las resistencias A y B y la diferencia de potencial aplicada. (Sol: 4 $\Omega$, 6 $\Omega$ y 65V).
#
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# ## Un motor está construido para trabajar con una corriente de 3.5A a una diferencia de potencial de 115V. Este motor se instalaen una red en la que la tensión es de 125V. Calcular el valor de la resistencia que hay que montar en serie con el motor para conservar el valor previsto de la corriente. (Sol: 2,85 $\Omega$)
#
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# ## Un circuito está formado por tres resistencias en serie. Cada resistencia tiene uin valor doble que la anterior. Al aplicar al circuito una d.d.p. (diferencia de potencial) de 100V circula una corriente de 2A.Calcular el valor de cada resistencia. (Sol: 7,14  , 14,28  , 28,56)
#
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# ## Hallar la resistencia de dos conductores de 2 y 8 ohmios respectivamente que están montados en paralelo. (Sol: 1,6 $\Omega$)
#
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# ## Hallar la resistencia de tres conductores de 20,30 y 40 ohmios respectivamente que están montados en paralelo.  (Sol: 9,23 $\Omega$

# %% [markdown]
# ## Cinco resistencias identicas se montan en paralelo sobre una línea de 100V. Calcular la corriente que pasa por el grupo sabiendo que la resistencia de cada lámpara vale 400 ohmios. (Sol: 1,25A)
#
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# ## Calcularla resistencia reducida del circuito que indica el esquema. (Sol: 2,25 $\Omega$)
#
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# ## CÁLCULO DE LA RESISTIVIDAD. Determinar la resistividad de un conductor que tiene 4 Km de longitud, 16 mm2de sección y una resistencia de 20 Ω. (Sol: 0,08 $ \frac{\Omega \cdot mm²}{m}$)

# %% [markdown]
# ## CÁLCULO DE LA LONGITUD DE UN CONDUCTOR. Calcular la longitud de un hilo de ferro-niquel de 2.6mm de diámetro y 500Ωde resistencia. (Resistividad= 0.8 $ \frac{\Omega \cdot mm²}{m}$) (Sol: 3318,3 m)

# %% [markdown]
# ## CÁLCULO DE LA INTENSIDAD DE UN CONDUCTOR. ¿Qué intensidad pasará a través de un conductor de aluminio de 2 Km de longitud y 1 $mm²$ de sección, cuando se le aplique una d.d.p. de 50V? (Sol: 0,89A)

# %% [markdown]
# ¿Qué intensidad circulará si la sección se hace el doble y la logitud la mitad? (Sol: 3,57A)

# %% [markdown]
# ## CÁLCULO DEL TIEMPO A PARTIR DE LA CANTIDAD DE CORRIENTE ¿Cuánto tiempo ha circulado una corriente, habiendo transportado 2050 culombios, si su intensidad es de 2 amperios? (Sol: 1025s)

# %% [markdown]
# ## CÁLCULO DE LA INTENSIDAD A PARTIR DE LA CANTIDAD DE CORRIENTE. Calcular la intensidad que circula por un circuito si en 5 horas, 30 minutos y 30 segundos han pasado un total de 39660 culombios (Sol: 2A)

# %% [markdown]
# ## CÁLCULO DE RESISTIVIDAD. Expresar en μΩcm las siguientes resistividades.
# 0.018 $ \frac{\Omega \cdot mm²}{m}$, 0.027$ \frac{\Omega \cdot mm²}{m}$, 0.12Ω $ \frac{\Omega \cdot mm²}{m}$

# %% [markdown]
# ## Potencia y Energía
#
# **Ejemplo 1**: Una bombilla tiene la siguiente indicación: 220V –100W. Calcula su resistencia.
#
# $P = \frac{V^2}{R}$ ,   de donde   $ R = \frac{V^2}{P}  = \frac{2202}{100} = 484 \Omega$
#
# **Ejemplo 2**: Calcula el consumo energético de una bombilla de 60 W al tenerla conectada mediahora.
#
# $E = P . t = 60w \frac {3600}{2s} = 108.000 J = 108 KJ$
#
# **Ejemplo 3**: Calcula cuánto costará tener encendidot toda la noche(8horas)unradiador de 2.500W, sabiendo que el coste del Kwh es de 2'80 euros.
#
# 2.500W = 2'5 Kw,  de donde  2'5 Kw . 8 h = 20 Kwh  y  multiplicando por el precio de 1Kwh tendremos: 20 Kwh . 2'80 $\frac {euros}{Kwh} = 56 euros.
#
# **Ejemplo 4**: Calcula la intensidad de corriente **I** en Amperios, que circula por un hilo conductor por el que han pasado 8trillones de electrones en 4 segundos.
#
# $I = \frac {N}{t}  = \frac {8 \cdot 10^18  e^{-}{4s} \cdot 1C/6’242.1018e-/s=0’32C/s=0'32A
#
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# ### Por un conductor circula una corriente de 1,5 A durante 5 min. Calcular carga que circula.  (Sol: 450 Coul)

# %% [markdown]
# ### Por  un  conductor  circula  una  corriente  de  0,5  A  y  la  carga  que  pasa  por  sección  es  de  200  Coul.  ¿Cuánto tiempo circula la corriente? (Sol: 6 min. 40 seg.)

# %% [markdown]
# ### El haz de electrones de una pantalla de T.V. tiene una intensidad de 0,25 A. Calcular la carga que circula en:
#
# * a) 10 seg.
#
# * b) 2minutos
#
# * c) 1 hora
#
# * d) Si 1 Coulomb equivale a 6,25 x 1018electrones. Calcular  el número de electrones que llega a la pantalla en los tres casos anteriores. (Sol: a) 2,5 Coul  b) 30 Coul  c) 900 Coul  d) $15,625 \cdot 10^{18} e \quad$ $187,5 \cdot 10^{18} e \quad$ $5625 \cdot 10^{18} e$

# %% [markdown]
# ### Por  un  conductor  circula  una  corriente  de  1,5  A  y  en  sus  extremos  hay  un  voltaje  de  90  volt.  Calcular:
#
# * a) La carga que circula en 5 minutos.
#
# * b) La resistencia del conductor.

# %% [markdown]
# ### ¿Qué intensidad pasará a través de un conductor de aluminio de 1Km de longitud y 3mm2de sección, cuando se le aplique una d.d.p. de 50V?

# %% [markdown]
# ### Un conductor metálico de 2m. de largo y $2mm^2$ de sección se conecta a 60 V y por él circula 0,2 A. Calcular:
#
# * a) R
#
# * b) $\varrho$

# %% [markdown]
# https://aliciadiazcobo.files.wordpress.com/2012/05/electricidad3c2baresueltos_formulari.pdf

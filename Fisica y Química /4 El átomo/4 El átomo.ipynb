# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Leyes-ponderales-y-modelo-atómico-de-Dalton" data-toc-modified-id="Leyes-ponderales-y-modelo-atómico-de-Dalton-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Leyes ponderales y modelo atómico de Dalton</a></span><ul class="toc-item"><li><span><a href="#Ley-de-conservación-de-la-masa" data-toc-modified-id="Ley-de-conservación-de-la-masa-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Ley de conservación de la masa</a></span></li><li><span><a href="#Ley-de-las-proporciones-definidas" data-toc-modified-id="Ley-de-las-proporciones-definidas-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Ley de las proporciones definidas</a></span></li><li><span><a href="#Modelo-atómico-de-Dalton" data-toc-modified-id="Modelo-atómico-de-Dalton-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Modelo atómico de Dalton</a></span></li></ul></li><li><span><a href="#Los-modelos-del-átomo:-Thomson-y-Rhuterford" data-toc-modified-id="Los-modelos-del-átomo:-Thomson-y-Rhuterford-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Los modelos del átomo: Thomson y Rhuterford</a></span><ul class="toc-item"><li><span><a href="#Modelo-de-Thomson" data-toc-modified-id="Modelo-de-Thomson-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Modelo de Thomson</a></span></li><li><span><a href="#Modelo-de-Rhuterford" data-toc-modified-id="Modelo-de-Rhuterford-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Modelo de Rhuterford</a></span></li></ul></li><li><span><a href="#Números-atómico-y-másico,-y-masa." data-toc-modified-id="Números-atómico-y-másico,-y-masa.-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Números atómico y másico, y masa.</a></span><ul class="toc-item"><li><span><a href="#Número-atómico-y-número-másico" data-toc-modified-id="Número-atómico-y-número-másico-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Número atómico y número másico</a></span></li><li><span><a href="#Masa-atómica" data-toc-modified-id="Masa-atómica-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Masa atómica</a></span></li><li><span><a href="#La-composición-centesimal" data-toc-modified-id="La-composición-centesimal-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>La composición centesimal</a></span></li><li><span><a href="#¿SE-PUEDEN-ALTERAR-LOS-ÁTOMOS?" data-toc-modified-id="¿SE-PUEDEN-ALTERAR-LOS-ÁTOMOS?-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>¿SE PUEDEN ALTERAR LOS ÁTOMOS?</a></span></li></ul></li><li><span><a href="#Isótopos-y-sus-aplicaciones" data-toc-modified-id="Isótopos-y-sus-aplicaciones-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Isótopos y sus aplicaciones</a></span></li><li><span><a href="#La-corteza-atómica.-Modelo-de-Bohr" data-toc-modified-id="La-corteza-atómica.-Modelo-de-Bohr-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>La corteza atómica. Modelo de Bohr</a></span></li><li><span><a href="#Configuración-electrónica" data-toc-modified-id="Configuración-electrónica-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Configuración electrónica</a></span><ul class="toc-item"><li><span><a href="#Jerarquía:-Niveles,-subniveles-y-orbitales" data-toc-modified-id="Jerarquía:-Niveles,-subniveles-y-orbitales-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Jerarquía: Niveles, subniveles y orbitales</a></span></li><li><span><a href="#1ª-ordenación:-Niveles-o-capas" data-toc-modified-id="1ª-ordenación:-Niveles-o-capas-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>1ª ordenación: Niveles o capas</a></span></li><li><span><a href="#2ª-ordenación:-Subniveles" data-toc-modified-id="2ª-ordenación:-Subniveles-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>2ª ordenación: Subniveles</a></span></li><li><span><a href="#3ª-ordenación:-Orbitales" data-toc-modified-id="3ª-ordenación:-Orbitales-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>3ª ordenación: Orbitales</a></span></li><li><span><a href="#Resumen" data-toc-modified-id="Resumen-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Resumen</a></span></li><li><span><a href="#Otros-recursos" data-toc-modified-id="Otros-recursos-6.6"><span class="toc-item-num">6.6&nbsp;&nbsp;</span>Otros recursos</a></span></li><li><span><a href="#Configuración-electrónica-de-un-átomo" data-toc-modified-id="Configuración-electrónica-de-un-átomo-6.7"><span class="toc-item-num">6.7&nbsp;&nbsp;</span>Configuración electrónica de un átomo</a></span></li><li><span><a href="#Ejercicios-de-onfiguraciones-electrónicas" data-toc-modified-id="Ejercicios-de-onfiguraciones-electrónicas-6.8"><span class="toc-item-num">6.8&nbsp;&nbsp;</span>Ejercicios de onfiguraciones electrónicas</a></span></li></ul></li></ul></div>

# %% [markdown]
# # El Atomo
#
# Adaptado de:
#
# Savia Digital (SM)
#
# ]e-educativa](http://e-ducativa.catedu.es/44700165/aula/archivos/repositorio/1000/1162/html/21_partculas_subatmicas.html)

# %% [markdown]
# ## Leyes ponderales y modelo atómico de Dalton

# %% [markdown]
# ### Ley de conservación de la masa
# <font color = "blue">
#
# (Antoine Lavoisier) La masa total de las sustancias que intervienen en una transformación química permanece constante.
# </font>

# %% [markdown]
# ### Ley de las proporciones definidas
# <font color = "blue">
#
# (Joseph Proust) Siempre que dos elementos se combinan para originar un compuesto determinado, lo hacen en una relación de masa constante.
# </font>

# %% [markdown]
# ###  Modelo atómico de Dalton
# <font color ="blue">
#
# [video](https://youtu.be/0AcIYA2A12Q)
#
# * **Toda la materia está hecha de átomos**. Absolutamente todo lo que conocemos está hecho de átomos tanto en la tierra como en el universo conocido. Cada uno de los elementos está hecho de átomos.
#
# * **Los átomos son indivisibles e indestructibles**. Dalton pensaba que los átomos eran las partículas más pequeñas de la materia y eran químicamente indestructibles.
#
# * **Todos los átomos de un elemento dado son idénticos** . Para un elemento determinado, todos sus átomos tienen la misma masa y las mismas características.
#
# * **Los átomos de diferentes elementos varían en masa y propiedades**. Cada elemento tiene átomos de características y masa diferentes.
#
# * **Los compuestos están formados por una combinación de dos o más tipos diferentes de átomos**. Un compuesto determinado siempre tiene los mismos tipos de átomos combinados y en las mismas proporciones.
#
# * **Una reacción química es una reorganización de átomos**. Los átomos no pueden crearse, son indivisibles e indestructibles. Cualquier reacción química simplemente cambia la forma en la que los átomos están agrupados.
#
# Consideraciones adicionales del Modelo de Dalton.
#
# Adicionalmente a estos principios básicos, Dalton propuso que los átomos de dos elementos que interactúan entre sí para formar moléculas, obedecen la **Ley de Conservación de la Masa**. Lo que significa que el número y las clases de átomos que contienen las moléculas son iguales al número y tipo de átomos de los productos usados en la reacción química.
#
# Otro importante aspecto de su teoría fue la **Ley de Proporciones Múltiples** que indica que al combinar los átomos de dos elementos, solo se pueden combinar de acuerdo a una relación de números enteros como 1:1, 2:1, 2:2, etc. Por ejemplo, el agua $H_2O$ se combina en la proporción 2:1, lo que significa que tiene dos átomos de hidrógeno y uno de oxígeno. Por lo tanto, ninguna otra proporción de estos elementos puede usarse para producir agua. No se puede producir agua usando 3 átomos de hidrógeno y dos de oxígeno (3:2).
#
# </font>

# %% [markdown]
# ## Los modelos del átomo: Thomson y Rhuterford
#
# Image(url= https://www.youtube.com/watch?v=qzXvNh-mwys)

# %% [markdown]
# ### Modelo de Thomson
# <font color="blue">
#
# * Los átomos **se comportan** como pequeñísimas masas esféricas con carga positiva, dentro de las cuales se encuentran los electrones con carga negativa, en posiciones fijas.
#
# El modelo atómico de Thomson es una teoría sobre la estructura atómica propuesta en 1904 por Thomson, quien descubrió el electrón1​ en 1897, pocos años antes del descubrimiento del protón y del neutrón.
#
# En el modelo, el átomo está compuesto por electrones de carga negativa en un átomo positivo, incrustados en este al igual que las pepitas en una sandía. Por esta comparación, fue que el supuesto se denominó «Modelo del pudín de pasas».
#
# Thomson postulaba que los electrones se distribuían uniformemente en el interior del átomo, suspendidos en una nube de carga positiva. El átomo se consideraba como una esfera con carga positiva con electrones repartidos como pequeños gránulos.
#
# </font>

# %% [markdown]
# ![atomoThonsom.jpeg](attachment:atomoThonsom.jpeg)

# %% [markdown]
# ### Modelo de Rhuterford
# <font color ="blue">
#
# El átomo esta constituido por:
#
# **Núcleo:** O zona central en la que se encuentran los protones, la carga total positiva pequeñísimas masas esféricas) y la mayor parte de la masa del átomo, aportada por los protones y neutrones.
#
# **Corteza:** Zona externa donde se hallan los electrones girando alrededor del núcleo.
#
# Hay tantos electrones en la corteza como protones en el núcleo, por lo que el conjunto del átomo es eléctricamente neutro.
#
# * Los núcleos de todos los átomos poseen carga positiva.
#
# * La masa del núcleo es prácticamente igyual a la masa del átomo.
#
# * El núcleo tiene carga positiva debido a unas partículas llamadas protones, de igual carga que los electrones (que se encuentran en la corteza), pero opuesta, siendo neutra la carga total del átomo.
#
# * El radio de un átomo es, aproximadamente, cien mil veces mayor que el radio del núcleo.
#
# </font>

# %%
from IPython.display import Image
Image(url='http://e-ducativa.catedu.es/44700165/aula/archivos/repositorio/1000/1162/html/ScientificLinux-Logo.gif')
# Out:
# <img src="http://e-ducativa.catedu.es/44700165/aula/archivos/repositorio/1000/1162/html/ScientificLinux-Logo.gif"/>

# %% [markdown]
# Señala cuáles de las siguientes afirmaciones relativas al modelo atómico de Rutherford son correctas:
#
# a) Los átomos son, en su mayor parte, espacio vacío.
#
#
# b) Los átomos tienen su masa distribuida uniformemente en todo su volumen.
#
#
# c) El núcleo del átomo es neutro.
#
#
# d) Los electrones se encuentran fuera del núcleo, orbitando en torno a él.

# %% [markdown]
# Incorrectas a) y d)
#
# La mayor parte del átomo es vacio, pues casi toda la masa se encuentra en el núcleo, que ocupa un volumen muy pequeño respecto al total del átomo, y está cargado positivamente. En torno a este núcleo se encuentran girando los electrones en órbitas circulares.

# %% [markdown]
# ## Números atómico y másico, y masa.
#
# <font color ="blue">
#
# Los átomos de los distintos elementos se identifican por dos números: el **número atómico (Z)** y el **número másico (A)**.
#
# </font>

# %% [markdown]
# ### Número atómico y número másico
#
# <font color ="blue">
#
# * **Número atómico** es el número de protones que tiene un átomo en el núcleo.  **Z = Número de protones**
#
# * **Número másico** es la suma de protones (Z) y neutrones (N) del núcleo.   **A = Z + N**
#
#     </font>

# %% [markdown]
# Completa el siguiente texto:
#
# A pesar de que en los primeros modelos el _______ se consideraba indivisible, distintos experimentos mostraron que estaba formado por partículas más pequeñas que se denominaron _______ . En la teoría de Rutherford existen ______ partículas subatómicas: el electrón, con carga______ y masa muy pequeña, el ______, cargado positivamente y el neutrón que no tiene _______ eléctrica; estas dos últimas partículas tienen aproximadamente la ______ masa. Mientras que los electrones se encuentran en la corteza, el protón y el neutrón se ubican en el ______atómico.

# %% [markdown]
# <font color ="blue">
#
# Un átomo se identifica mediante su número atómico y su número másico, y se representa como se indica en la imagen.
#
# </font>

# %% [markdown]
# ![representacion_atomos.jpeg](attachment:representacion_atomos.jpeg)

# %% [markdown]
# Indica el número de protones, neutrones y electrones del siguiente átomo neutro: $⁴_2He$

# %% [markdown]
# ### Masa atómica

# %% [markdown]
# <font color ="blue">
#
# **Átomo de referencia**
#
# El átomo tomado como referencia para la medida de la masa de los átomos es el carbono 12C.
#
# Al átomo de carbono se le asigna el valor exacto de 12.
#
# **Unidad de masa atómica (u)**
#
# Se define como la doceava parte de la masa del átomo de carbono $^{12}_6C \;$ y equivale a una masa
# de $1,66 \cdot 10^{–27} \;$ kg.
#
# Así, a la masa del carbono le corresponde 12 u, y a la masa del hidrógeno, 1 u.
#
# **Masa atómica relativa**
#
# La masa atómica relativa es el número de veces que la masa de un átomo contiene a la unidad de masa atómica. La masa atómica relativa del carbono es 12.
#
# </font>

# %% [markdown]
# Ejemplo:  La masa atómica del oxígeno es de 16,0 u. Calcula su masa atómica en gramos.
#
# Solución: La masa en gramos de un átomo de oxígeno es:$\quad (16,0u)⋅(1,66⋅10^{−24}g/u) = 2,66⋅10^{−23}$

# %% [markdown]
# <font color ="blue">
#
# Indica las afirmaciones que son incorrectas sobre la masa atómica.
#
# * La masa atómica del oxígeno es de 16 u, lo cual significa que un átomo de oxígeno tiene una masa 16 veces mayor que la unidad de masa atómica.
#
# * La masa atómica de un átomo es la masa del áto­mo expresada en gramos.
#
# * La unidad de masa atómica es un átomo de carbono.
#
# **Masa molecular**
#
# La masa molecular es la suma de las masas atómicas de todos los átomos que forman la molécula. Se expresa en unidades de masa atómica (u).
# </font>

# %% [markdown]
# ### La composición centesimal
#
# <font color ="blue">
#
# La composición centesimal es la masa de cada elemento que hay en 100 g del compuesto. El porcentaje se calcula a partir de la ecuación:
#
# $$\% \; elemento = \frac {n \cdot masa \; atómica \; del \; elemento}{masa \; molecular \; del \; compuesto } \cdot 100$$
#
# Donde n es el número de átomos del elemento en la fórmula.
#
# </font>

# %% [markdown]
# Ejemplo: Composición centesimal de la calcopirita  $\quad CuFeS_2$
#
# $\quad CuFeS_2 = \% \; Cu = \frac{1 \cdot (63,6u)}{183,5u} \cdot 100 = 34,6 \%$

# %% [markdown]
# <font color ="blue">
#
# ### ¿SE PUEDEN ALTERAR LOS ÁTOMOS?
#
# **A) Quitar o añadir electrones**
#
# * **IONES** son átomos que han perdido o ganado electrones, y por tanto tienen carga eléctrica, es decir, no son neutros.
#
# * **ANIÓN**  Es un átomo que ha ganado electrones. Tiene carga negativa (electrones de más).
#
# * **CATIÓN**  Es un átomo que ha perdido electrones. Tiene carga positiva (electrones de menos).
#
# Puedes ver cómo se forman los iones en este enlace
# </font>

# %% [markdown]
#  ![iones.jpeg](attachment:iones.jpeg)

# %% [markdown]
# <font color ="blue">
#
# **B) Quitar o añadir neutrones**
#
# * **ISÓTOPOS** son átomos de un mismo elemento que tienen el  mismo  número  de  protones  (igual  número atómico, Z) y distinto  número  de  neutrones  (distinto  número másico, A)
#
# **Los  isótopos  de  un  elemento  se  diferencian  en  el  número  de neutrones**  que  hay  en  sus núcleos,  pero  no  en  el  número  de protones.
#
# Hay unos 300 isótoposque llamamos naturales porque  se encuentran en la Tierra.
#
# Hay 21 elementos que no tienen isótopos naturales: flúor, sodio, fósforo, cobalto, oro...
#
# Los isótopos artificiales se obtienen en el laboratorio aumentando el número de neutrones de un átomo al bombardear sus núcleos con otras partículas que contienen neutrones.
#
# Muchos isótopos son inestables y se desintegran fácilmente, emitiendo partículas con cierta energía o radiaciones que pueden  detectarse  mediante  aparatos  adecuados. Son  los  **isótopos  radiactivos**.  Se  pueden  emplear  para  tres aplicaciones fundamentalmente: como fuente de energía, en investigaciones científicas y en medicina. Los residuosque se originan en el uso de los radioisótopos son su  principal inconveniente
# ![isotopo_H_he.jpeg](attachment:isotopo_H_he.jpeg)
#  </font>

# %% [markdown]
# ## Isótopos y sus aplicaciones

# %% [markdown]
# <font color = "blue">
#
# Los isótopos son átomos de un mismo elemento que tienen el mismo número de protones (igual número atómico), pero diferente número de neutrones (distinto número másico).
#
# Conociendo la masa atómica (A1, A2…) y la abundancia (%1, %2,…) de cada uno de los isótopos de un elemento, se puede calcular la masa media ponderada de cada elemento:
#
# $$Masa \; media \; ponderada = \frac{A_1 \dot (\%_1) + A_2 \cdot (\%_2) + ... + A_n \cdot (\%_n)}{100}$$
#  </font>

# %% [markdown]
# **Ejercicios**
#
# a) Realiza una tabla indicando el número de partículas subatómicas para los tres isótopos del carbono: $^{12}_6C,^{13}_6C ; y \; ^{14}_6C$
#
#
# b) Calcula la masa atómica media del carbono a partir de las masas de los tres isótopos del carbono y de los porcentajes de abundancia:
# C-12 = 98,9 %, C-13 = 1,11 %, C-14 ≈ 0 (trazas).

# %% [markdown]
# **Ejercicios**
#
# c) El cloro (Z = 17) es un elemento utilizado generalmente en la desinfección de piscinas. En la naturaleza hay dos isótopos del cloro: el Cl-35  ($^{35}_{17}tCl$), con una abundancia del 75 %, y el Cl-37 ($^{37}_{17}CL)$, con una abundancia del 25 %. Determina:
#
#     * Los protones y los neutrones que hay en el núcleo de cada uno de estos isótopos.
#
#     * La masa atómica media del cloro expresada en u.
#
#     * MarkdownEl número de átomos de cloro que hay en 15 g de cloro.
#
# Solución:

# %% [markdown]
# d) El tecnecio-99 y el talio-201 son isótopos radiactivos que se utilizan como trazadores en medicina, para el estudio del músculo cardiaco. Se inyectan en el torrente sanguíneo y se hace un seguimiento del trazador para observar a qué zonas del corazón llega la sangre adecuadamente. Investiga el nombre de dicha técnica y enumera qué otros órganos del cuerpo humano pueden estudiarse así.

# %% [markdown]
# ##  La corteza atómica. Modelo de Bohr
#
# ![atomo_Borhn.jpg](attachment:atomo_Borhn.jpg)

# %% [markdown]
# <font color="blue">
#
# * El electrón no puede girar en cualquier órbita, sino sólo en un cierto número de órbitas estables, a determinadas distancias del núcleo. En el modelo de Rutherford se aceptaba un número infinito de órbitas.
#
# * Cuando el electrón gira en estas órbitas no emite energía (energía constante).
#
# * Cuando un átomo estable sufre una interacción, como puede ser el impacto de un electrón o el choque con otro átomo, uno de sus electrones puede pasar a otra órbita estable o ser arrancado del átomo.
#
# * Cada capa, llamada también nivel de energía, tiene un número diferente de electrones. El número de electrones por nivel es $2n^2$, donde n es el número del nivel (n = 1, 2, 3,...).
# </font>

# %% [markdown]
# ## Configuración electrónica
# [configuración electrónica](https://sites.google.com/site/fiquizona/fisica-y-quimica-3o-eso/configuracion-electronica)

# %% [markdown]
# <font color="blue">
#
# Es una forma de representar la forma en la que se distribuyen los electrones de un átomo en los distintos niveles y subniveles de energía.
#
# ### Jerarquía: Niveles, subniveles y orbitales
#
# No todos los alumnos de Andalucía están en el mismo sitio. Los alumnos de los centros andaluces se ordenan según diferentes criterios y niveles. La primera diferenciación será según la provincia donde viva cada uno. Dentro de la provincia, según el pueblo o ciudad. Dentro de la ciudad, hay diferentes institutos y colegios y los alumnos irán a unos u otros dependiendo de su edad. En un mismo instituto, los alumnos se reparten a su vez por ciclos, según un orden creciente de edades. Dentro de cada ciclo, hay diferentes cursos. Dentro de cada curso hay alumnos que están en diferentes clases (3ºA, 3ºB, 3ºC, etc) según las asignaturas optativas que haya escogido, etc.
#
# Vemos que hay una **organización jerárquica** o una serie de niveles que, siguiendo distintos criterios, caracterizan a cada alumno y ayudan a diferenciarlo administrativamente de los demás.**A un alumno se le puede etiquetar como "De un centro asturiano>de Langreo>de La Felguera>de los Dominicos>de 3º de ESO>de 3ºB> alumno nº X de la lista". Este etiquetado, que podemos llamar la "configuración" del alumno lo caracteriza y sirve para distinguirlo y referirnos a él de manera específica**.
#
# Del mismo modo, los electrones que tiene un átomo no se encuentran todos en la misma órbita a la misma distancia del núcleo, sino que se encuentran repartidos en diferentes agrupaciones o niveles jerárquicos dentro del átomo, que a su vez están dentro de otros niveles. **Hay varios niveles jerárquicos que hay que comprender**. Reciben los siguientes nombres:
#
# **nivel  >  subnivel  >  orbital**
#
#
# </font>

# %% [markdown]
# <font color="blue">
#
# ### 1ª ordenación: Niveles o capas
#
# En primer lugar, los electrones se reparten  según las distintas órbitas posibles alrededor del núcleo. Cada una de estas órbitas o capas tiene un nivel de energía diferente. Los electrones se disponen en capas o niveles. Cada nivel se caracteriza por tener una energía distinta, hay 7 niveles de energía. Se les designa por números del 1 al 7 (y en cursos más avanzados, por letras)
#
# $$n = 1,  n = 2,  n = 3,...,  n = 7$$
#
# ![niveles_capas.jpeg](attachment:niveles_capas.jpeg)
#
# Físicamente, cada nivel de energía representa una órbita más cercana o lejana al núcleo
#
# El número máximo de electrones que caben en cada capa o nivel viene dado por
#
# $$2 n^2$$
#
# Así para la capa n = 3,  el número máximo de electrones que caben es  2 x 32 = 2 x 9 = 18
# </font>

# %% [markdown]
# ### 2ª ordenación: Subniveles
#
#
#
#
# Además, dentro de cada nivel, hay distintos subniveles. en total hay 4 y se representan por una letra:
#
# s, p, d, f
#
# Un truco para recordarlas podría ser "espada fea". Estos subniveles también tienen distinta energía. El número de subniveles que puede haber en cada capa no es siempre el mismo. Depende de cada capa. El truco para saberlo es sencillo: En la capa 1 hay un subnivel (el s). En la capa 2 hay 2 subniveles (s, p). En la capa 3 hay 3 (s, p, d), y en la capa 4 hay 4 (s, p, d, f).
#
# ![niveles_energia_Bohrn.jpeg](attachment:niveles_energia_Bohrn.jpeg)
# </font>

# %% [markdown]
# ### 3ª ordenación: Orbitales
#
# <font color="blue">
#
#
#
#     </font>

# %% [markdown]
# <font color="blue">
#
# **A) Orden de llenado**
#
# El orden de llenado de los orbitales (de menor a mayor energía) se ha determinado experimentalmente, y, salvo excepciones de algunos elementos, sigue la secuencia:
# 1s < 2s < 2p < 3s < 3p < 4s < 3d < 4p < 5s < 4d < 5p <6s < 4f
#
# Esta secuencia se suele representar en un diagrama llamado diagrama de Moeller:
#
# ![diagrama_Moeller.jpeg](attachment:diagrama_Moeller.jpeg)
#
# **B) Forma de escribir la configuración electrónica**
#
# Hay que indicar los distintos niveles y subniveles del átomo que se van llenando con electrones, hasta llegar al  total de electrones que tenga el átomo.
# Tomemos como ejemplo el caso del Helio. El Helio tiene de número atómico 2. Tiene dos protones. Por tanto, en estado neutro tendrá dos electrones. Estos dos electrones son los que tenemos que distribuir.
#
# La forma de expresarlo es poniendo en primer lugar un número que nos dice de qué nivel de energía estamos hablando.
#
# Detrás y en minúscula, la letra del subnivel (s, p, d f) y un exponente (o superíndice, es decir, un numerito encima a la derecha) sobre la letra del subnivel,  que nos dice el número de electrones que hay en ese subnivel.
#
# </font>

# %% [markdown]
# <font color="blue">
#
# ### Resumen
#
# adaptado de [apuntes de 3º ESO F&Q](https://www.educa2.madrid.org/web/cesar.arenas/apuntes3fyq)
#
# ![capas&niveles.jpeg](attachment:capas&niveles.jpeg)
#
# * Los electrones del átomo se distribuyen en órbitas o capas alrededor del núcleo.
#
# * Las distintas órbitas se identifican por un número entero, n, llamado número cuánti-
# co principal. Así para la primera capa (la más próxima al núcleo n = 1; para la se-
# gunda n = 2; para la tercera n = 3...
#
# * El número de capas u órbitas que posee un elemento viene dado por el número del
# periodo en que está situado en la tabla periódica.
#
# Para distribuir los electrones en las capas se deben tener en cuenta unas reglas ob-
# tenidas de la experimentación:
#
# * 1. Las capas se van llenando por orden: primero se llena la de n = 1, a con-
# tinuación n= 2, después n = 3 ...
#
# * 2. No se puede empezar a llenar un nivel superior si aún no está lleno el in-
# ferior.
#
# * 3. El número máximo de electrones que se puede alojar en cada capa es $2n²$, siendo n el número de capa.:
#
# </font >

# %% [markdown]
# ![capa_de_valencia.jpeg](attachment:capa_de_valencia.jpeg)

# %% [markdown]
# ### Otros recursos
#
#     Animación: [Forma de orbitales atómicos (Educaplus)](http://www.educaplus.org/game/orbitales-atomicos)
#
#     Imagen: [Configuración electrónica sobre la tabla periódica](https://drive.google.com/file/d/1hBRjcxw40zW9owENStapJiYaAAVCBS01/view)
#
#     Imagen: [Configuración electrónica y bloques de la tabla periódica](https://drive.google.com/file/d/1ZX7d8VECeh9PQ72509SOCEwNhkmow5LE/view)
#
#     Vídeo YouTube: [Teoría con ejemplos explicados (canal Amigos de la Química) (17 minutos)](https://www.youtube.com/watch?v=4MMvumKmqs4)
#
#     Video YouTube: [Ejercicios resueltos de configuración electrónica, y colocación en periodos y grupos (profesor10demates) (8 minutos)](https://www.youtube.com/watch?v=nXH3EVGtp1k)
#
#     Video YouTube: [Más ejercicios resueltos de configuración electrónica y colocación en periodos y grupos (profesor10demates) (7 minutos)](https://www.youtube.com/watch?v=8-VSlvFm0Zg)
#
#     Video YouTube: [Ejercicios resueltos de configuración electrónica (IONES) y colocación en periodos y grupos (profesor10demates) (6 minutos)](https://www.youtube.com/watch?v=144Xzywdf3c)
#
#     Imagen: [Configuración electrónica de los elementos hasta Z=89](https://drive.google.com/file/d/1wJ6Lsrvt1VBQbwXNiix5WXzMkH-VYfXj/view)

# %% [markdown]
# <font color="blue">
#
# ### Configuración electrónica de un átomo
#
# Para obtener la configuración electrónica de un átomo:
#
# * 1. Considera el número de electrones que debes distribuir. Recuerda que el nú-
# mero de electrones en un átomo neutro viene dado por el número atómico Z.
#
# * 2. Vete colocando los electrones por orden en los niveles de cada capa. Cuando
# un nivel se complete, pasa al siguiente (ayúdate del diagrama de Möeller)
#
# * 3. Cuando hayas colocado todos los electrones habrás terminado.
#
# * 4. Ordena por capas la configuración obtenida.
# </font>

# %% [markdown]
# ![configuracion-electronica-de-los-elementos.jpg](attachment:configuracion-electronica-de-los-elementos.jpg)

# %% [markdown]
#  La distribución de los electrones en las capas se denomina configuración electrónica y se realiza de la siguiente manera:
#
#     La 1ª capa puede contener, como máximo, 2 electrones.
#     La 2ª capa puede contener, como máximo, 8 electrones. Comienza a llenarse una vez que la 1ª ya está completa.
#     La 3ª capa puede contener, como máximo, 18 electrones. Comienza a llenarse una vez que la 2ª capa ya está completa.
#
#
# [adaptado de](http://e-ducativa.catedu.es/44700165/aula/archivos/repositorio/1000/1162/html/34_configuracin_electrnica.html)
#
# **Principio de mínima energía**
#
# * En el proceso de llenado, los electrones van llenando los subniveles por orden de energía creciente de los mismos, primero el de menor energía (subnivel 1s), posteriormente eDado el elemento de número atómico 38:
# a) Escribe su configuración electrónica. l 2s, 2p, ... y así sucesivamente.
#
# * Los electrones que se encuentran en un mismo nivel energético (igual n) se dice que se encuentran en la misma capa.
#
# * Según esto, el orden de llenado de los primeros subniveles será el siguiente:
# 1s 2s 2p 3s 3p 4s 3d 4p 5s 4d 5p
#
# Este orden puede recordarse de una forma sencilla mediante el diagrama de Moeller o "regla del serrucho", que se muestra en la figura siguiente, en la que se van llenando los subniveles en diagonal, a partir del **1s** y leyendo de arriba abajo.
#
# </font>

# %%
    ¿Cuál de estos no es un isótopo del Hidrógeno?

A) deuterio
B) cuterio
C) protio
D) tritiofrom IPython.display import Image
Image(url='https://upload.wikimedia.org/wikipedia/commons/d/dd/Electron_configuration_order.gif')
# Out:
#   File "<ipython-input-2-cc84def5ab46>", line 3
#     A) deuterio
#      ^
# SyntaxError: unmatched ')'

# %% [markdown]
# Animación. [Hoogli](https://commons.wikimedia.org/wiki/File:Electron_configuration_order.gif)
#
# Licencia Creative Commons

# %% [markdown]
# ![orden_llenado_capas.jpeg](attachment:orden_llenado_capas.jpeg)

# %% [markdown]
# **Ejercicio**
#
# **Dado el elemento de número atómico 38:**
# **a) Escribe su configuración electrónica.**
#
# Como su número atómico es 38, el átomo tendrá 38 electrones. Su configuración electrónica será la correspondiente a aplicar el orden de llenado a sus 38 e-.
#
# 1s2 2s2 2p6 3s2 3p6 4s2 3d10 4p6 5s2
#
# El elemento en cuestión es el estroncio.
#
# **b) ¿Cuántos orbitales hay en su subnivel 3p? ¿Cuántos electrones caben en él?**
#
# El orbital 3p tiene n = 3 y l = 1, por tanto tendrá 2·1 + 1 = 3 orbitales.
#
# Dado que en cada orbital pueden ubicarse dos electrones, cabrán 6 electrones en él.
#
# **c) Si el átomo capta un nuevo electrón, ¿cuál será la nueva configuración electrónica del átomo? ¿Para cuántos electrones más tendría capacidad esta nueva capa?**
#
# Ahora tendremos 39 electrones y la nueva configuración electrónica sería:
#
# 1s2 2s2 2p6 3s2 3p6 4s2 3d10 4p6 5s2 4d1
#
# La nueva capa que ha comenzado a llenarse es una capa de tipo d (l = 3) que tiene 5 orbitales y por lo tanto capacidad para 10 electrones. Debido a que ya hay uno alojado, podrá admitir hasta 9 e- más.

# %% [markdown]
# ### Ejercicios de onfiguraciones electrónicas
#
# [Cajón de CienciasEjercicios de configuraciones electrónicas](http://www.cajondeciencias.com/Descargas%20quimica/ER%20configuraciones%20electronicas.pdf)
#
# 1) Escribe las configuraciones electrónicas de los siguientes elementos
#
# a) N  b) P  c) Ar  d) Ti  e) V  f) Ge  g) Br  h) Sr  i) Au  j) Be  k) Xe  l) K  m) S  n) Sb
#
# 2) Escribe la configuración electrónica de los siguientes iones:
# a) F-
#
# b) Ca2+
#
# c) O2-
#
# d) Co3+
#
# e) Fe2+
#
# f) N3-
#
# g) Na+
#
# i) Cl-
#
# j) Al3+
#
# k) Se2-
#
# l) H+
#
# m) Ba2+
#
# n) P

# %% [markdown]
# Cajón de Ciencias
#
# 1) Escribe las configuraciones electrónicas de los siguientes elementos
#
# a) N (Z=7) 1s2 2s2 2p3
#
# b) P (Z = 15)1s2 2s2 2p6 3s2 3p3
#
# c) Ar (Z = 18)1s2 2s2 2p6 3s2 3p6
#
# d) Ti (Z = 22)1s2 2s2 2p6 3s2 3p6 4s2 3d2
#
# e) V (Z = 23)1s2 2s2 2p6 3s2 3p6 4s2 3d3
#
# f) Ge (Z = 32)1s2 2s2 2p6 3s2 3p6 4s2 3d10 4p2
#
# g) Br (Z = 35)1s2 2s2 2p6 3s2 3p6 4s2 3d10 4p5
#
# h) Sr (Z= 38)1s2 2s2 2p6 3s2 3p6 4s2 3d10 4p6 5s2
#
# i) Au (Z=79)1s2 2s2 2p6 3s2 3p6 4s2 3d10 4p6 5s2 4d10 5p6 6s2 4f14 5d9
#
# j) Be (Z = 4)1s2 2s2
#
# k) Xe (Z = 54)1s2 2s2 2p6 3s2 3p6 4s2 3d10 4p6 5s2 4d10 5p6
#
# l) K (Z = 19)1s2 2s2 2p6 3s2 3p6 4s1
#
# m) S (Z = 16)1s2 2s2 2p6 3s2 3p4
#
# n) Sb (Z = 51)1s2 2s2 2p6 3s2 3p6 4s2 3d10 4p6 5s2 4d10 5p32)
#
# Escribe la configuración electrónica de los siguientes iones:Cuando tenemos iones, nos fijamos primero en el número atómico del elemento. En condicionesnormales, como hemos dicho, ese número atómico (Z) se corresponde con el número de electrones.Pero en los iones hay electrones de más o de menos, dependiendo de si se trata de iones negativos(aniones) o positivos (cationes):- En los iones negativos, hay un electrón de más por cada carga negativa.- En los iones positivos, hay un electrón de menos por cada carga positiva.
#
# a) F-  (Z = 9, 10 electrones)1s2 2s2 2p6
#
# b) Ca2+ (Z = 20, 18 electrones)1s2 2s2 2p6 3s2 3p6
#
# c) O2- (Z = 8, 10 electrones)1s2 2s2 2p6
#
# d) Co3+ (Z = 27, 24 electrones)1s2 2s2 2p6 3s2 3p6 4s2 3d4
#
# e) Fe2+ (Z = 26, 24 electrones)1s2 2s2 2p6 3s2 3p6 4s2 3d4
#
# f) N3- (Z = 7, 10 electrones)1s2 2s2 2p6
#
# g) Na+ (Z = 11, 10 electrones)1s2 2s2 2p6i) Cl- (Z = 17, 18 electrones)1s2 2s2 2p6 3s2 3p6
#
# j) Al3+ (Z = 13, 10 electrones)1s2 2s2 2p6
#
# k) Se2- (Z = 34, 36 electrones)1s2 2s2 2p6 3s2 3p6 4s2 3d10 4p6
#
# l) H+ (Z = 1, 0 electrones)1s0m) Ba2+ (Z = 56, 54 electrones)1s2 2s2 2p6 3s2 3p6 4s2 3d10 4p6 5s2 4d10 5p6
#
# n) P3- (Z = 15, 18 electrones)1s2 2s2 2p6 3s2 3p6

# %% [markdown]
# ** Ejercicios adaptados](http://www.cajondeciencias.com/Descargas%20quimica/Configuracion%20electronica.pdf)
#
# A practicarEscribe las configuraciones electrónicas de los siguientes elementos:
#
# a) C6
#
# b) Kr36
#
# c) K19
#
# d) Ag47
#
# e) Br35
#
# f) Sc21
#
# g) S16
#
# h) Co27
#
# i) O16
#
# j) Pb82
#
# Soluciones:
#
# a) C6 → 1s2 2s2 2p2
#
# b) Kr36 → 1s2 2s2 2p6 3s2 3p6 4s2 3d10 4p6
#
# c) K19 → 1s2 2s2 2p6 3s2 3p6 4s1
#
# d) Ag47 → 1s2 2s2 2p6 3s2 3p6 4s2 3d10 4p6 5s2 4d9
#
# e) Br35 → 1s2 2s2 2p6 3s2 3p6 4s2 3d10 4p5
#
# f) Sc21 → 1s2 2s2 2p6 3s2 3p6 4s2 3d1
#
# g) S16 → 1s2 2s2 2p6 3s2 3p4
#
# h) Co27 → 1s2 2s2 2p6 3s2 3p6 4s2 3d7
#
# i) O16 → 1s2 2s2 2p6 3s2 3p4
#
# j) Pb82 → 1s2 2s2 2p6 3s2 3p6 4s2 3d10 4p6 5s2 4d10 5p6 6s2 4f14 5d10 6p

# %% [markdown]
# http://e-ducativa.catedu.es/44700165/aula/archivos/repositorio/1000/1162/html/21_partculas_subatmicas.html

# %% [markdown]
# # Repaso
# Adaptado de : [Modelos atómicos 3º ESO](https://www.thatquiz.org/es/preview?c=cyafrg37&s=pmrwb0)

# %% [markdown]
#     1. Cientifico que propuso un modelo de átomo no macizo compuesto de NUCLEO y CORTEZA
#
# A) Dalton
#
# B) Thomson
#
# C) Rutherford
#
# D) Mendeleievisotopos_hidrogeno.jpeg

# %% [markdown]
#     2. En el NUCLEO del átomo hay
#
# A) Protones y electrones
#
# B) Electrones
#
# C) Protones
#
# D) Protones y neutrones

# %% [markdown]
#     3. En la CORTEZA del átomo hay
#
# A) Protones en movimiento
# isotopos_hidrogeno.jpeg
# B) Protones en posiciones fijas
#
# C) Electrones en posiciones fijas
#
# D) Electrones en movimiento

# %% [markdown]
#     4. Los PROTONES son partículas subatómicas de carga
#
# A) ninguna
#
# B) Positiva
#
# C) Neutros
#
# D) Negativa

# %% [markdown]
#     5. Los PROTONES tienen una masa
#
# A) unas 2000 veces mayor que los electrones
#
# B) Igual que los electronesisotopos_hidrogeno.jpeg
#
# C) No tienen masa apreciable
#
# D) son más pequeños que los electrones

# %% [markdown]
#     6. Al número de PROTONES de un átomo se le denomina
#
# A) Número isotópico (I)
#
# B) Número másico (A)
#
# C) Número de Avogadro (N)
#
# D) Número atómico (Z)

# %% [markdown]
#     7. Los átomos que tienen IGUAL nº de PROTONES y DISTINTO nº de NEUTRONES se denominan
#
# A) Neutrosisotopos_hidrogeno.jpeg
#
# B) Equivalentes
#
# C) Isótopos
#
# D) Gases nobles

# %% [markdown]
#     ¿Cuál de estos no es un isótopo del Hidrógeno?
#
# A) deuterio
# B) cuterio
# C) protio
# D) tritio

# %% [markdown]
# ![isotopos_hidrogeno.jpeg](attachment:isotopos_hidrogeno.jpeg)

# %% [markdown]
#     9. Los isótopos de un elemento tiene todos el mismo número de
#
# A) masa
#
# B) protones y neutrones
#
# C) neutrones
#
# D) protones

# %% [markdown]
#     10. A la suma de PROTONES y NEUTRONES de un átomo se la denomina
#
# A) Número protoneutrónico (P)
#
# B) Número nuclear (N)
#
# C) Número másico (A)
#
# D) Número atómico (Z)

# %% [markdown]
#     11. Un elemento que pierde electrones se transforma en
#
# A) catión
#
# B) neutro
#
# C) isótopo
#
# D) anión

# %% [markdown]
#     12. Un elemento que gana electrones se transforma en un
#     19. El nº de protones que tiene este átomo es
#
# A) 27
# B) 14
# C) 10
# D) 13
# A) isótopo
#
# B) catión
#
# C) neutro
#
# D) anión

# %% [markdown]
#     13. Los     19. El nº de protones que tiene este átomo es
#
# A) 27
# B) 14
# C) 10
# D) 13átomos que tienen el mismo nº atómico y distinto nº másico son
#
# A) isótopos
#
# B) aniones
#
# C) átomos diferentes
#
# D) cationes

# %% [markdown]
#     14. Un á    19. El nº de protones que tiene este átomo es
#
# A) 27
# B) 14
# C) 10
# D) 13tomo que tiene 12 protones y 10 electrones es
#
# A) catión
#
# B) imposible
#
# C) isótopo
#
# D) anión

# %% [markdown]
#     15. El modelo atómico que propone que los átomos son indivisibles es el de
#
# A) Dalton
#
# B) Rutherford
#
# C) Demócrito    15. El modelo atómico que propone que los átomos son indivisibles es el de
#
# A) Dalton
# B) Rutherford
# C) Demócrito
# D) Thompson
#
# D) Thompson

# %% [markdown]
#     16. Los rayos de un tubo de vacío que se dirigen hacia el polo positivo se llaman
#
# A) catódicos
#
# B) catalíticos
#
# C) católicos
#
# D) neutrones

# %% [markdown]
#     17. El modelo conocido como "pudding de pasas" se debe a
#
# A) Bohr
#
# B) Rutherford
#
# C) Thompson
#
# D) Dalton

# %% [markdown]
#     18. Cuando frotamos un objeto se queda con carga eléctrica, eso es porque ...
#
# A) cambia neutrones por electrones
#
# B) pierde o gana protones
#
# C) no puede perder ni ganar nada
#
# D) pierde o gana electrones

# %% [markdown]
#     19. El nº de protones que tiene este átomo es
#
# ![atomo3.jpeg](attachment:atomo3.jpeg)
#
#
# A) 27
#
# B) 14
#
# C) 10
#
# D) 13

# %% [markdown]
#     20. Este átomo tiene
#
# ![atomo3.jpeg](attachment:atomo3.jpeg)
#
#
# A) 3 electrones más que protones
#
# B) 3 protones más que electrones
#
# C) tres neutrones más que protones
#
# D) todas las subpertículas igual

# %% [markdown]
# ![isotopos.jpeg](attachment:isotopos.jpeg)

# %% [markdown]
#     21. Estos átomos se diferencian en el nº de
#
# A) neutrones
#
# B) electrones
#
# C) en nada
#
# D) protones

# %% [markdown]
#     22. El experimento que se muestra en la figura sirvió para saber que
#
# A) que el átomo está formado por electrones
#
# B) que hay partícula en un átomo
#
# C) el átomo estaba formado por un núcleo y una corteza
#
# D) que el átomo no tiene cargas eléctricas

# %% [markdown]
# ![Rutherford.jpg](attachment:Rutherford.jpg)

# %% [markdown]
#     23. Este átomo es un
#
# ![isotopo%205.jpeg](attachment:isotopo%205.jpeg)
#
# A) isótopo
#
# B) catión
#
# C) neutro    23. Este átomo es un
#
# A) isótopo
# B) catión
# C) neutro
# D) anión
#
# D) anión

# %% [markdown]
#     24. Este átomo tiene
#
# ![isotopo%205.jpeg](attachment:isotopo%205.jpeg)
#
# A) un protón de más
#
# B) igual nº de protones y de neutrones
#
# C) 1 electrón de más
#
# D) diferente nº de neutrones

# %% [markdown]
#     25. Un átomo puede tener en su última capa como máximo
#
# A) 8 electrones
#
# B) depende del nº de capa
#
# C) 2 electrones
#
# D) 36 electrones

# %% [markdown]
#     27. ¿Cuántos protones tiene este átomo?
#
# ![atomo6.jpeg](attachment:atomo6.jpeg)
#
# A) 10
#
# B) 9
#
# C) 19
#
# D) 8

# %% [markdown]
#     28. El nº de neutrones que tiene es
#
# A) 19
# B) 9
# C) 10
# D) 8

# %% [markdown]
#     29. Indica cuál de estas afirmaciones es cierta
#
# ![atomo7.jpeg](attachment:atomo7.jpeg)
#
# A) tiene el mismo nº de protones que de neutrones
#
# B) tiene 24 protones
#
# C) tiene más neutrones que protones
#
# D) tiene 24 neutrones

# %% [markdown]
#     30. Indica cuál de las siguientes afirmaciones es falsa para este átomo de Argon
#
# ![atomo8.jpeg](attachment:atomo8.jpeg)
#
# A) tiene 18 protones
#
# B) tiene el mismo nº de protones y de neutrones
#
# C) tiene el mismo nº de protones que de electrones
# ![atomo8.jpeg](attachment:atomo8.jpeg)
# D) tiene 18 neutrones

# %% [markdown]
# # OTRAS REFERENCIAS
#
# Fiquizona: [Física y Química 3º ESO](https://sites.google.com/site/fiquizona/fisica-y-quimica-3o-eso#ancla3)
#
# [Repaso de modelos atómicos](https://www.thatquiz.org/es/practicetest?7zcud8lx16gt1)

# %%
from IPython.display import Image

PATH = "/media/enri/Mi_Proyecto/Apoyo-3-ESO/Fisica y Química  3º ESO/4 El átomo/"
Image(filename = PATH + "isotopo 5.jpeg")

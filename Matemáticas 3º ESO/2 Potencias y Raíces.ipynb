# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Potencias-con-exponente-entero-positivo" data-toc-modified-id="Potencias-con-exponente-entero-positivo-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Potencias con exponente entero positivo</a></span></li><li><span><a href="#Notación-científica" data-toc-modified-id="Notación-científica-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Notación científica</a></span></li><li><span><a href="#Raíz-cuadrada" data-toc-modified-id="Raíz-cuadrada-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Raíz cuadrada</a></span></li><li><span><a href="#Radicales-de-cualquier-índice" data-toc-modified-id="Radicales-de-cualquier-índice-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Radicales de cualquier índice</a></span></li></ul></div>

# %% [markdown]
# # Potencias de exponente entero

# %% [markdown]
# **Si no compartes el conocimiento no sirve para nada.** [Michio Kaku](https://www.youtube.com/watch?v=6rDxlolYUQw)
#
# * [Referencia bibliográfica para los ejercicios](https://www.alfonsogonzalez.es/asignaturas/3_eso/ejercicios_3_eso_propuestos.php)
# * Referencia bibliográfica para la teoria: Texto de SM y referencias que se hacen a páginas de Internet.

# %% [markdown]
# ## Potencias con exponente entero positivo

# %% [markdown]
# <font color = "blue">
# * $a^b = \underbrace{a\cdots a}_{b \; \text{veces}}$
#
# * $-a^b = -(\underbrace{a\cdots a}_{b \; \text{veces}})$
#
# * $(-a)^b = \underbrace{(-a)\cdots (-a)}_{b \; \text{veces}}$
#
#  </font>

# %% [markdown]
# <font color = "blue">
# **Propiedades** Las potencias con exponente entero positivo cumplen las siguientes propiedades.
#
# * **Potencias con la misma base**
#
#  $$ a^m \cdot a^n = a^{m+n}$$
#
#  $$ \frac {a^m} {a^n} = a^{m-n} \quad si \quad a \neq 0 \quad y \quad \; si \; m > n$$
#     </font>

# %% [markdown]
# <font color = "blue">
# **Potencias con el mismo exponente**
#
# $$a^n \cdot b^n =(a \cdot b)^n$$
#
# $$ \frac {a^n}{b^n} = (\frac {a}{b})^n \quad si \quad b \neq  0$$
# </font>

# %% [markdown]
# <font color = "blue">
# **Potencia de potencia**
#
# $$ (a^m)^n = a^{m \cdot n}$$
#     </font>

# %% [markdown]
# <font color = "blue">
# ## Potencias con exponente 0
#
# $$ \frac{a^n}{a^n } = a^{n-n} = a^0 \quad y \quad \frac{a^n}{a^n } = 1 \quad luego \quad a^0 = 1$$
# </font>

# %% [markdown]
# <font color = "blue">
# ## Potencias con exponente entero negativo
#
# $$a^n \cdot a^{-n} = a^{n+(-a)} = 1 \cdot$$ $$\cdot a^{-n} = \frac {1}{a^n}$$
#
# **Una potencia de exponente entero negativo es la inversa de la potencia con exponente entero positivo**.
#
# $$Si \quad a ≠ 0  \Rightarrow  a^{-n} = \frac {1}{}a^n$$
#
# </font>

# %% [markdown]
# <font color = "blue">
# Para determinar el signo de una potencia con exponente entero debemos tener en cuenta  lo siguiente:
#
# a).- Las potencias con exponente par son siempre positivas. Esto quiere decir que, si tenemos una potencia $a^b$, entonces:
#
# * Si a es positivo y b es par, entonces $a^b$ es positivo.    $\quad 3³ = 3 \cdot 3 \cdot 3 = 27$
#
# * Si a es negativo y b es par, entonces $a^b$ es positivo.    $\quad (-3)² = (-3) \cdot (-3) = 9
# </font>

# %% [markdown]
# <font color = "blue">
# b).- Las potencias con exponente impar siempre tienen el mismo signo que su base. Esto quiere decir que, si tenemos una potencia $a^b$, entonces:
#
# * Si a es positivo y b es impar, entonces a^b es positivo.  $\quad 2³ = 2 \cdot 2 \cdot 2 = 8$
#
# * Si a es negativo y b es impar, entonces a^b es negativo.   $\quad (-3^3) = (-3) \cdot (-3) \cdot (-3) = -27$
# </font>

# %% [markdown]
# **Ejercicio 01.**  Calcula las siguientes potencias.
#
# a) $\quad 3^2 =---- \quad$ b) $\quad 7^4 = ---- \quad$ c) $\quad (-9)^2 = ---- \quad$ d) $\quad (-5)^3 = ---- \quad$
#
# e) $\quad (-2,02)^4 = ---- \quad$ f) $\quad( - \frac {5}{8})^5 = ---- \quad$ g) $\quad (4,25)^4 = ---- \quad$
#
# f) $\quad (- \frac{1}{2})^3 = ---- \quad$ i) $\quad (-14,32)^8 =  = ---- \quad$

# %% [markdown]
# **Ejercicio 02.** Calcula $(−0,8)^2) \;$ , $(−0,8)^3 \;$ y $(−0,8)^4 \;$ . ¿Cuál es mayor?

# %% [markdown]
# **Ejercicio 03.** Expresa en forma de potencia.
#
# a) $3 \cdot 9 \cdot 9 \cdot 3 = ---- \quad$  b) $\quad (-\frac{1}{7}) \cdot \frac{1}{7} \cdot \frac{1}{7} =----$

# %% [markdown]
# **Ejercicio 04.** Calcula estas potencias.
# a) $\quad 7^{-3} = ---\quad$ b) $\quad 7^1 = ---\quad$ c) $\quad 7^{-1} = ---\quad$ d) $\quad (-5)^{-2} = ---\quad$
#
# e) $\quad (-5)^0 = ---\quad$ f) $\quad (-5)^{-1} = ---\quad$ g) $\quad (\frac{8}{5})^{-4} = ---\quad$ h) $\quad (\frac{8}{5})^1 =---  \quad$i) $\quad (\frac{8}{5 })^{-1} = ---\quad$ j) $\quad (- \frac{8}{5})^{-5} = ---\quad$ k) $\quad (- \frac{8}{5})^{0} = ---\quad$ l) $(- \frac{8}{5})^{-1} = --- \quad$

# %% [markdown]
# **Ejercicio 05.** Contesta si es verdadero o falso.
# a) Una potencia de exponente negativo es siempre positiva.
# b) Una potencia de exponente 0 es siempre positiva.

# %% [markdown]
# **Ejercicio 06.** ¿Cómo calcularías (0,2) −3 ?

# %% [markdown]
# **Ejercicio 07,** Calcula
#
# a) $\quad (8 \cdot 4)^3 = ---\quad$  b) $\quad [(-1) \cdot (-4)]^4 = ---\quad$ c) $\quad (\frac {4}{5})^3 = ---\cdot$
#
# d) $\quad (6,5)^{-2} = ---\quad$ e) $\quad [(-3) \cdot 5]^{-2} = ---\quad$ f) $\quad (-\frac{5}{3})^{-2} = ---\quad$

# %% [markdown]
# **Ejercicio 09.** Señala qué desigualdad es cierta.
#
# a) $\quad (\frac{1}{2})^3 < \frac{1}{4} \quad$ $ \quad [2 \cdot (-1)]^4 < \frac {1}{2}$

# %% [markdown]
# **Ejercicio 10.** Expresa como una sola potencia.
#
# a) $\quad 5^4 \cdot 5^6 = ---\quad$ b) $\quad (-9)^6 : (-9)^2 = ---\quad$
#
# c) $\quad (\frac{5}{6})^{10} : (\frac{5}{6})^6 = ---\quad$ d) $\quad [(\frac {3}{5})^4]^2 = ---\quad$
#
# e) $\quad [2^2]^3 = ---\quad$ f) $\quad [(-2)^2]^3 = ---\quad$
#
# g) $\quad (- \frac{4}{3})^3 \cdot (- \frac{4}{3})^3 = ---\quad$ h) g) $\quad (- \frac{4}{3})^3 : (- \frac{4}{3})^3 = ---\quad$

# %% [markdown]
# **Ejercicio 11.** Simplifica estas operaciones con potencias.
#
# a) $\quad (4^3 \cdot 4^2)^3 = ---\quad$  b) $\quad [(-5)^3 : (-5)^2]^2 = ---\quad$
#
# c) $\quad [(4,2)^4 \cdot (4,2)^3 ]^4 = ---\quad$ d) $\quad (7^{11} : 7^5) = ---\quad$
#
# d) $\quad (7^2 \cdot 9^4)^2 = ---\quad$ e) $\quad [(-3)^5 \cdot 4^5]^2 = ---\quad$

# %% [markdown]
# **Ejercicio 12.** Expresa como una sola potencia.
# $\quad 2^5 \cdot 4^3 = ---\quad$ b) $\quad (3 ^{-5} \cdot 9^3)^{-2} = ---\quad$

# %% [markdown]
# ## Notación científica
#
# <font color = "blue">
# Un número está escrito en notación científica si es de la forma: $a \cdot 10^p, donde 1 < a < 10 y p es un número entero.
#
# El exponente p se llama orden de magnitud.
#
# </font>

# %% [markdown]
# <font color = "blue">
#
# **Paso de notación decimal a notación científica.**
#
# * El valor de a se obtiene desplazando la coma.
#
#     </font>

# %% [markdown]
# **Ejercicio 13.** Escribe en notación científica.
# a) 493.000.000
#
# b) 315.000.000.000
#
# c) 0,0004464
#
# d) 12,00056
#
# e) 253
#
# f) 256,256

# %% [markdown]
# **Ejercicio 15.** Estos números no están correctamente escritos en notación científica.
# Corrígelos.
#
# a) 0,247 ⋅ 10 8
#
# b) 24,7 ⋅ 10 8
#
# c) 0,247 ⋅ 10 −8

# %% [markdown]
# **Ejercicio 17.** Resuelve estas operaciones utilizando la notación científica.
#
# d) (34 ⋅ 10 3 ) ⋅ (25,2 ⋅ 10 −2 )
#
# e) (0,75 ⋅ 10 7 ) : (0,3 ⋅ 10 3 )
#
# f) (8,06 ⋅ 10 9 ) ⋅ (0,65 ⋅ 10 7 )
#
# a) 7,77 ⋅ 10 9 − 6,5 ⋅ 10 7
#
# b) 0,05 ⋅ 10 2 + 1,3 ⋅ 10 3
#
# c) 37,3 ⋅ 10 −2 + 0,01 ⋅ 10 2
#
# No olvides expresar el resultado en notación científica.

# %% [markdown]
# <font color = "blue">
#
# **Paso de notación científica a notación decimal.**
#
# * Se multiplica el número decimal por la potencia de 10 indicada.
# </font>

# %% [markdown]
# **Ejercicio 14.** Escribe, con todas sus cifras, los siguientes números dados en notación
# científica.
#
# a) 2,51 ⋅ 10 6
# b) 9,32 ⋅ 10 −8
# c) 3,76 ⋅ 10 12

# %% [markdown]
# ## Raíz cuadrada
# <font color = "blue">
#
# La raíz cuadrada de un número real a es otro número real b tal que al elevarlo al cuadrado se obtiene a.
#
# Si $ a \geq  0, \quad \sqrt{a}= b  \Rightarrow   b^2=a$
#
# El símbolo $\sqrt{a}$, se lee radical de índice 2 de a.
#
# </font>

# %% [markdown]
# ## Radicales de cualquier índice
#
# <font color = "blue">
#
# La raíz enésima de un número a es un número b tal que al elevarlo a n se obtiene a.
#
# $ \sqrt[n]{a} = b   \Rightarrow   b^n=a$
#
# El símbolo n√a
# se llama radical de índice n y radicando a.
#
# </font>

# %% [markdown]
# ## Radicales equivalentes
#
# <font color = "blue">
#
# Dos radicales son equivalentes cuando tienen la misma raíz.
#
# </font>

# %% [markdown]
# **Ejercicio 20.** Clasifica los siguientes números decimales en racionales o irracionales.
# a) 4,325325325...
# b) 4,330300300030000300000...
# c) 1,23233233323333233333...
# d) 3,12359474747...

# %% [markdown]
# **Ejercicio 21.** Escribe cinco números racionales y cinco irracionales.

# %% [markdown]
# **Ejercicio 22.** ¿Puedes anotar un número irracional con un solo dígito después de la coma?
# ¿Y con dos dígitos?

# %% [markdown]
# **Ejercicio 23.** Trunca y redondea los siguientes números a las centésimas y las milésimas.
#
# a) 1,234564668
#
# b) 2,7
#
# c) 4,51
#
# d) 1,43643625
#
# e) 2,222
#
# f) 3,127
#
# g) 5
#
#
# h) 3,222464
#
# i) 3
#
# j) 1,6467538
#
# k) 1,1234...
#
# l) 5,5

# %% [markdown]
# **Ejercicio 24.** Halla el error absoluto y relativo cometido en cada uno de los casos
# del ejercicio anterior.

# %% [markdown]
# **Ejercicio 25.** Al aproximar el peso de un gusano de 2,1236 g hemos cometido un error
# absoluto de 0,0236 g. Y al aproximar el peso de un buey de 824,36 kg hemos
# cometido un error de 4,36 kg. ¿En qué caso hemos cometido mayor error?

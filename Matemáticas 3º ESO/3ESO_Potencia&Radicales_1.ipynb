# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Potencias" data-toc-modified-id="Potencias-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Potencias</a></span></li><li><span><a href="#Radicales" data-toc-modified-id="Radicales-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Radicales</a></span><ul class="toc-item"><li><span><a href="#Raíz-cuadrada" data-toc-modified-id="Raíz-cuadrada-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Raíz cuadrada</a></span></li><li><span><a href="#Radicales-de-cualquier-índice" data-toc-modified-id="Radicales-de-cualquier-índice-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Radicales de cualquier índice</a></span></li><li><span><a href="#Radicales-equivalentes" data-toc-modified-id="Radicales-equivalentes-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Radicales equivalentes</a></span></li><li><span><a href="#Reducción-a-índice-común" data-toc-modified-id="Reducción-a-índice-común-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Reducción a índice común</a></span></li><li><span><a href="#Extracción-e-introducción-de-factores-en-un-radical" data-toc-modified-id="Extracción-e-introducción-de-factores-en-un-radical-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Extracción e introducción de factores en un radical</a></span></li><li><span><a href="#Suma-y-resta-de-radicales-semejantes" data-toc-modified-id="Suma-y-resta-de-radicales-semejantes-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Suma y resta de radicales semejantes</a></span></li><li><span><a href="#Potencias-de-exponente-fraccionario." data-toc-modified-id="Potencias-de-exponente-fraccionario.-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Potencias de exponente fraccionario.</a></span></li><li><span><a href="#Conversión-de-índices-y-suma-de-radicales" data-toc-modified-id="Conversión-de-índices-y-suma-de-radicales-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Conversión de índices y suma de radicales</a></span></li><li><span><a href="#Sumas-con-radicales-como-denominadores" data-toc-modified-id="Sumas-con-radicales-como-denominadores-2.9"><span class="toc-item-num">2.9&nbsp;&nbsp;</span>Sumas con radicales como denominadores</a></span></li><li><span><a href="#Productos-de-radicales" data-toc-modified-id="Productos-de-radicales-2.10"><span class="toc-item-num">2.10&nbsp;&nbsp;</span>Productos de radicales</a></span></li><li><span><a href="#Divisiones-con-radicales" data-toc-modified-id="Divisiones-con-radicales-2.11"><span class="toc-item-num">2.11&nbsp;&nbsp;</span>Divisiones con radicales</a></span></li><li><span><a href="#Simplificar" data-toc-modified-id="Simplificar-2.12"><span class="toc-item-num">2.12&nbsp;&nbsp;</span>Simplificar</a></span></li><li><span><a href="#Jerarquía-al-resilver-radicales" data-toc-modified-id="Jerarquía-al-resilver-radicales-2.13"><span class="toc-item-num">2.13&nbsp;&nbsp;</span>Jerarquía al resilver radicales</a></span></li><li><span><a href="#Potencias-de-un-radical" data-toc-modified-id="Potencias-de-un-radical-2.14"><span class="toc-item-num">2.14&nbsp;&nbsp;</span>Potencias de un radical</a></span></li><li><span><a href="#Binomios-y-radicales" data-toc-modified-id="Binomios-y-radicales-2.15"><span class="toc-item-num">2.15&nbsp;&nbsp;</span>Binomios y radicales</a></span></li><li><span><a href="#Operaciones-mixtas-con-radicales" data-toc-modified-id="Operaciones-mixtas-con-radicales-2.16"><span class="toc-item-num">2.16&nbsp;&nbsp;</span>Operaciones mixtas con radicales</a></span></li><li><span><a href="#Raices-de-raices" data-toc-modified-id="Raices-de-raices-2.17"><span class="toc-item-num">2.17&nbsp;&nbsp;</span>Raices de raices</a></span></li><li><span><a href="#Racionalizar-radicales" data-toc-modified-id="Racionalizar-radicales-2.18"><span class="toc-item-num">2.18&nbsp;&nbsp;</span>Racionalizar radicales</a></span></li><li><span><a href="#Leyes-de-potencias-en-radicales" data-toc-modified-id="Leyes-de-potencias-en-radicales-2.19"><span class="toc-item-num">2.19&nbsp;&nbsp;</span>Leyes de potencias en radicales</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Potencias y radicales
# [superprofe](https://www.superprof.es/apuntes/escolar/matematicas/aritmetica/reales/radicales-2.html#tema_potencias-racionales)
#
# [Exámenes de matemáticas](https://lasmatematicas.eu/docs/eso/3eso/examenes/15-notacion-cientifica-radicales-1.pdf)

# %% [markdown]
# ## Potencias

# %% [markdown]
# ## Radicales

# %% [markdown]
# ### Raíz cuadrada
# <font color = "blue">
#
# La raíz cuadrada de un número real a es otro número real b tal que al elevarlo al cuadrado se obtiene a.
#
# Si $ a \geq  0, \quad \sqrt{a}= b  \Rightarrow   b^2=a$
#
# El símbolo $\sqrt{a}$, se lee radical de índice 2 de a.
#
# </font>

# %% [markdown]
# ### Radicales de cualquier índice
#
# <font color = "blue">
#
# La raíz enésima de un número a es un número b tal que al elevarlo a n se obtiene a.
#
# $ \sqrt[n]{a} = b   \Rightarrow   b^n=a$
#
# El símbolo n√a
# se llama radical de índice n y radicando a.
#
# </font>

# %% [markdown]
# ### Radicales equivalentes
#
# <font color = "blue">
#
# Dos radicales son equivalentes cuando tienen la misma raíz.
#
# </font>

# %% [markdown]
# ### Reducción a índice común
#
# <font color = "blue">
#
# El índice común es el m,c,m. de todos los índices.
#
# ejemplo:  Poner a común índice los radicales:  $\sqrt{2} \quad $ $\sqrt[3]{2² \cdot 3²} \quad $ $\sqrt[4]{2² \cdot 3³} \quad $
#
# MCM(2,3,4) = 12
#
# $\sqrt[12]{2⁶} \quad $     $\quad \sqrt[12]{2⁸ \cdot {3⁸}} \quad $ $\quad \sqrt[12]{2⁶ \cdot 3⁹} \quad $
#
# </font>

# %% [markdown]
# 1) $\quad \sqrt{2} \qquad$ $\quad \sqrt [3]{2^2  \cdot 3^2} \qquad$ $\qquad \sqrt [4]{2^2 \cdot 3^3}$
#
# 2)

# %% [markdown]
# ### Extracción e introducción de factores en un radical
#
# <font color = "blue">
#
# Ejemplo de extracción:
#
# $\quad \sqrt[3]{5488}= \quad$ $\quad \sqrt[3]{2⁴ \cdot 7³} \quad$ $\quad \sqrt[3]{2⁴} \cdot \sqrt[3]{7³}=$   $\quad 7  \sqrt[3]{2⁴}= \quad$   $\quad 7\cdot 2 \sqrt[3]{2} =\quad$  $\quad 14\sqrt[3]{2} \quad$
#
# Ejemplos de introducción:
#
# $-5 \quad \sqrt[3 ]{ 2}= \quad$  $\quad \sqrt[ 3]{(-5)³ } \sqrt[3]{2}= \quad$  $\quad \sqrt[3 ]{ -125 \cdot 2}= \quad$  $\quad \sqrt[3 ]{-250 }= \quad$
#
# $\sqrt[4]{3  \sqrt{3^9 }}= \quad$  $\sqrt[4 ]{\sqrt{3²} \sqrt{3⁹}}= \quad$  $\sqrt[ 4]{\sqrt{3² \cdot 3⁹} }= \quad$  $\sqrt[8 ]{ \sqrt{3^{2+9}}}= \quad$  $\sqrt[ 4]{ \sqrt{3^{11}}}= \quad$  $\sqrt[ 8]{ 3^{11}}= \quad$
#
# </font>

# %% [markdown]
# 1.- $ \sqrt{2 \cdot 3² \cdot 5⁵}$
#
# 2.- $ \sqrt[4]{2⁷ \cdot 3^{14} \cdot 5⁴}$

# %% [markdown]
# 1) $\qquad 2 \sqrt{3}$
#
# 2) $\qquad 2² \cdot 3³ \cdot \sqrt[4]{6}$

# %% [markdown]
# ### Suma y resta de radicales semejantes
#
# <font color = "blue">
#
# Dos radicales son semejantes si tienen el mismo índice y el mismo radicando.
#
# Para sumar o restar radicales semejantes, se extrae la raíz como factor común y se operan los coeficientes.
#
# $a \sqrt[n]{ c} + b \sqrt[n]{c}=  (a+b) \sqrt[n]{c}$
#
# Ejemplo:
#
# $-3 \sqrt[3]{ 2} +5 \sqrt[3]{2}=  (-3+5) \sqrt[3]{2} = 2 \sqrt[3]{2}$
#
# Dos radicales son semejantes si tienen el mismo índice y el mismo radicando.
#
# Para sumar o restar radicales semejantes, se extrae la raíz como factor común y se operan los coeficientes.
#
# $a \sqrt[n]{ c} + b \sqrt[n]{c}=  (a+b) \sqrt[n]{c}$
#
# Ejemplo:
#
# $-3 \sqrt[3]{ 2} +5 \sqrt[3]{2}=  (-3+5) \sqrt[3]{2} = 2 \sqrt[3]{2}$
#
# </font>

# %% [markdown]
# a) $\qquad 2 \sqrt{2} - 4 \sqrt{2}+ \sqrt {2}$
#
# b) $\qquad 3 \sqrt[4]{5} - 2 \sqrt[4]{5 }- \sqrt[4]{5}$
#
# c) $\qquad \sqrt{12} - 3\sqrt{3} + 2 \sqrt{75}$
#
# d) $\qquad \sqrt[4]{4} + \sqrt[6]{8} - \sqrt[12]{64}$

# %% [markdown]
# ### Potencias de exponente fraccionario.
#
# <font color = "blue">
#
# Si a > 0, se define potencia de base a y exponente fraccionario como:
#
# $(-4)\frac{6}{4} = \sqrt[4]{(-4)⁶} = \sqrt[4]{4096}$
#
# </font>

# %% [markdown]
# ### Conversión de índices y suma de radicales

# %% [markdown]
#  a) $\qquad 2 \sqrt{12}-3\sqrt{75}+\sqrt{27}$
#
#  b) $\qquad \sqrt{24}-5\sqrt{6}+\sqrt{486}$
#
#  c) $\qquad 2\sqrt{5}+\sqrt{45}+\sqrt{180}-\sqrt{80}$
#
#  d) $\qquad \sqrt[3]{53}-\sqrt[3]{16}+\sqrt[3]{250}$

# %% [markdown]
# ### Sumas con radicales como denominadores

# %% [markdown]
# a) $\qquad \sqrt{2}+ \frac{1}{\sqrt{2}}$
#
# b) $\qquad \sqrt[3]{16}+\sqrt[3]{250}+\sqrt[6]{4}- \frac{1}{\sqrt[3]{4}}$

# %% [markdown]
# ### Productos de radicales

# %% [markdown]
# a) $\qquad \sqrt{2}\cdot\sqrt{6}$
#
# b) $\qquad \sqrt{3} \cdot \sqrt[3]{9} \cdot [4]{27}$
#
# c) $\qquad \sqrt{12} \cdot \sqrt[3]{36}$

# %% [markdown]
# ### Divisiones con radicales

# %% [markdown]
# a) $\qquad \frac{\sqrt[6]{128}}{\sqrt[6]{16}}$
#
# b) $\qquad \frac{\sqrt[3]{4}}{\sqrt{2}}$
#
# c) $\qquad \frac{\sqrt{256}}{\sqrt[3]{16}}$

# %% [markdown]
# ### Simplificar

# %% [markdown]
# $\qquad \frac{\sqrt{a} \cdot \sqrt[3]{a^2} \cdot \sqrt[4]{a^3}}{\sqrt[6]{a^4}}$

# %% [markdown]
# ### Jerarquía al resilver radicales

# %% [markdown]
# $\qquad \sqrt[4] \frac {\sqrt[3]{2} }{\sqrt{\frac{1}{8}}}$

# %% [markdown]
# ### Potencias de un radical

# %% [markdown]
# a) $\qquad \sqrt[3]{18}^2$
#
# b) $\qquad \left (\frac{\sqrt[3]{12} \cdot \sqrt[4]{18}}{\sqrt{6}} \right )^4$

# %% [markdown]
# ### Binomios y radicales

# %% [markdown]
# a) $\qquad \left (\sqrt{7} - \sqrt{2}  \right )^2$
#
# b) $\qquad \left ( 2 - \sqrt{3} \right )^2$
#
# c) $\qquad \left ( \sqrt{5} + 2 \right ) \left ( \sqrt{5} - 2 \right )$
#
# d) $\qquad \left (2 \sqrt{5} + 3 \sqrt{2} \right ) \left (2 \sqrt{5} - 3 \sqrt{2} \right ) $

# %% [markdown]
# ### Operaciones mixtas con radicales

# %% [markdown]
# a) $\qquad \frac{1}{2-\sqrt{3}} \cdot \frac{1}{2+\sqrt{3}}$
#
# b) $  \sqrt{ \frac{a-b}{(a-b)^2} \cdot \frac{a+b}{a^2-b²}} $

# %% [markdown]
# ### Raices de raices

# %% [markdown]
# a) $\qquad \sqrt{\sqrt[3]{\sqrt[4]{2}}    }$
#
# a) $\qquad \sqrt{2 \sqrt[3]{2\sqrt[4]{2}}    }$
#
# a) $\qquad \sqrt{\sqrt[3]{ \sqrt{    \sqrt[3]{ 2 \sqrt{2}} } } }$

# %% [markdown]
# ### Racionalizar radicales

# %% [markdown]
# <font color = "green">
# **Ejemplo**
#
# $\frac{2}{3 \sqrt{2}} =  \frac {2\sqrt{2}}{3 \sqrt{2} \sqrt{2}}=$
#
# $=  \frac{2\sqrt{2}}{3(\sqrt{2})^2} =$
#
# $= \frac{2 \sqrt{2}}{3 \cdot 2} =$
#
# $= \frac{2 \sqrt{2}}{3 }  $
#
# </font>

# %% [markdown]
#  a) $\qquad \frac{2}{ 3 \sqrt[5]{4}}$
#
#  b) $\qquad \frac{2}{\sqrt{2} - \sqrt{3}}$
#
#  c) $\qquad \frac{2}{ 4 - 2 \sqrt{2}}$
#
#  d) $\qquad \frac{2 \sqrt{2}}{5 - 2 \sqrt{6}}$

# %% [markdown]
# ### Leyes de potencias en radicales

# %% [markdown]
# a) $\qquad \frac{5}{2 \quad{2}}$
#
# b) $\qquad \frac{1}{\sqrt[3]{3}}$
#
# c) $\qquad \frac{2}{3 + \sqrt{3}}$
#
# d) $\qquad \frac{\sqrt{2}}{\sqrt{3} - \sqrt{2}}$
#
# e) $\qquad \frac{3 \sqrt{2} - 2 \sqrt{3}}{3 \sqrt{2} + 2 \sqrt{3}}

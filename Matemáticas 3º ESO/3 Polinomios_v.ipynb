# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Expresiones-algebraicas" data-toc-modified-id="Expresiones-algebraicas-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Expresiones algebraicas</a></span></li><li><span><a href="#Valor-numérico-de-una-expresión-algebraica" data-toc-modified-id="Valor-numérico-de-una-expresión-algebraica-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Valor numérico de una expresión algebraica</a></span></li><li><span><a href="#Monomios" data-toc-modified-id="Monomios-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Monomios</a></span><ul class="toc-item"><li><span><a href="#Suma-y-diferencia-de-monomios" data-toc-modified-id="Suma-y-diferencia-de-monomios-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Suma y diferencia de monomios</a></span></li><li><span><a href="#Producto-de-un-número-por-un-monomio" data-toc-modified-id="Producto-de-un-número-por-un-monomio-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Producto de un número por un monomio</a></span></li><li><span><a href="#Producto-de-monomios" data-toc-modified-id="Producto-de-monomios-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Producto de monomios</a></span></li><li><span><a href="#Potencia-de-un-monomio" data-toc-modified-id="Potencia-de-un-monomio-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Potencia de un monomio</a></span></li><li><span><a href="#Cociente-de-monomios" data-toc-modified-id="Cociente-de-monomios-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Cociente de monomios</a></span></li></ul></li><li><span><a href="#Polinomios.-Operaciones-con-polinomios" data-toc-modified-id="Polinomios.-Operaciones-con-polinomios-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Polinomios. Operaciones con polinomios</a></span><ul class="toc-item"><li><span><a href="#Valor-numérico-de-polinomios" data-toc-modified-id="Valor-numérico-de-polinomios-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Valor numérico de polinomios</a></span></li><li><span><a href="#Suma-y-diferencia-de-polinomios" data-toc-modified-id="Suma-y-diferencia-de-polinomios-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Suma y diferencia de polinomios</a></span></li><li><span><a href="#Producto-de-un-número-por-un-polinomio" data-toc-modified-id="Producto-de-un-número-por-un-polinomio-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Producto de un número por un polinomio</a></span></li><li><span><a href="#Producto-de-polinomios" data-toc-modified-id="Producto-de-polinomios-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Producto de polinomios</a></span></li><li><span><a href="#Productos-de-polinomios.-Operaciones-combinadas" data-toc-modified-id="Productos-de-polinomios.-Operaciones-combinadas-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Productos de polinomios. Operaciones combinadas</a></span></li></ul></li><li><span><a href="#Cocientes-de-polinomios" data-toc-modified-id="Cocientes-de-polinomios-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Cocientes de polinomios</a></span><ul class="toc-item"><li><span><a href="#Extracción-de-un-factor-común" data-toc-modified-id="Extracción-de-un-factor-común-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Extracción de un factor común</a></span></li></ul></li><li><span><a href="#Identidades-notables" data-toc-modified-id="Identidades-notables-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Identidades notables</a></span><ul class="toc-item"><li><span><a href="#Cuadrado-de-una-suma" data-toc-modified-id="Cuadrado-de-una-suma-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Cuadrado de una suma</a></span></li><li><span><a href="#Cuadrado-de-una-diferencia" data-toc-modified-id="Cuadrado-de-una-diferencia-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Cuadrado de una diferencia</a></span></li><li><span><a href="#Suma-por-diferencia" data-toc-modified-id="Suma-por-diferencia-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Suma por diferencia</a></span></li></ul></li><li><span><a href="#Varios" data-toc-modified-id="Varios-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Varios</a></span></li></ul></div>

# %% [markdown]
# **Si no compartes el conocimeinto no sirve para nada.** [Michio Kaku](https://www.youtube.com/watch?v=6rDxlolYUQw)
#
# * [Ejercicios adaptados de ](https://www.alfonsogonzalez.es/asignaturas/3_eso/ejercicios_3_eso_resueltos.html)
#
# [EJERCICIOS de POLINOMIOS 3º ESO ALFONSO GONZÁLEZ I.E.S ](http://www.colexioabrente.com/descargas/mate/3eso/3eso2.1polinomios.pdf)
#
# * Referencia bibliográfica para la teoria: Texto de SM y referenciasque se citan a páginas de Internet.

# %% [markdown]
# # Polinomios

# %% [markdown]
# ## Expresiones algebraicas
#
# <font color="blue">
# Una **expresión algebraica** es una expresión matemática en la que intervienen letras, números y los signos de operaciones aritméticas.
#
# Las letras reciben el nombre de variables o indeterminadas y representan números o cantidades desconocidas.
#
# ejemplo: A(x)=2x²−3x+12
#
# </font>

# %% [markdown]
# ## Valor numérico de una expresión algebraica
#
# <font color="blue"><font color="blue">
#
# El valor numérico de una expresión algebraica es el resultado obtenido al sustituir cada una de las variables por números.
#     </font>

# %% [markdown]
# ## Monomios
#
# <font color="blue">
#
# Un **monomio** es una expresión algebraica formada por el producto de un número real por una o varias variables elevadas a exponentes naturales.
#
# Los monomios constan de dos partes:
#
# * **Parte literal:** formada por las variables y sus exponentes correspondientes.
# * **Coeficiente:** o parte numérica, es el número que multiplica a la parte literal.
#
# El **grado de un monomio** es la suma de todos los exponentes de las variables que intervienen en la parte literal.
#     </font>

# %% [markdown]
# 1.1 Indica el coeficiente, parte literal y grado de estos monomios.
#
# a) -3x³y²z⁴
#
# b) -5b²c³
#
# c) $x^{15}y$
#
# d) $ - \frac{2}{3} x y⁵$

# %% [markdown]
# 1.2 Determina si los monomios son semejantes o no.
#
# a) $\frac{1}{2}x²y³z⁵ \quad y \quad -5z⁵x²y³$
#
# b) 6x³y⁴  y 6x⁴y³
#
# c) xy³  y  -xy³
#
# d) 7x  y  -x

# %% [markdown]
# 1.3 Escribe el monomio opuesto de estos monomios.
#
# a) $\frac{1}{2}xy³z²$
#
# b) -4a²b³
#
# c) -5x⁹
#
# d) $9x^{11}$

# %% [markdown]
# 1.4 Escribe, si se puede, un monomio:
#
# a) coeficiente 2 y parte literal xy⁶.
#
# b) coeficiente −3 y semejante a −2x³.
#
# c) De grado 7 y semejante a -4x²y
#
# d) parte literal x³y⁴ y opuesto a −4x³y.

# %% [markdown]
# ### Suma y diferencia de monomios
#
# <font color="blue">
#
# Para sumar o restar monomios semejantes se suman o restan sus coeficientes y se escribe la misma parte literal que tienen ambos.
#
#
# Ejemplo
#
# Calcula la suma y la diferencia de $A(x) = 2x^2 $ y $B(x) = −x^2$.
#
# $A(x) + B(x) = 2x^2 − x^2 = (2 − 1)x^2 = x^2$
#
# $A(x) − B(x) = 2x^2 − (−x^2) = (2 + 1)x^2 = 3x^2$
#
# Calcula la suma y resta de A(x) = −3x y B(x) = 4x².
#
# A(x) + B(x) = −3x + 4x²
# A(x) − B(x) = −3x − 4x²
#
# </font>

# %% [markdown]
# **Ficha 1.** 1 Sumar monomios semejantes
#
# r) x²y² – 5x²y² – (3x²y² – 4x²y²) – 8x2²y²2 =
#
# u) $\frac{1}{2}x³ - \frac{5}{2}x³ + \frac{3}{2}x³$
#
# v) – (ab³ + a³b) – 3a³b + 5ab³ – (a³b – 2ab³) =
#
# y) $2a²b + 5a²b - \frac{2}{3} - a²b + \frac{a²b}{2}$
#
# z) -x³ + \frac{5x³}{4}- \frac{2x³}{3} + 3x³ + \frac{x³}{2}$     )
#
# α)  7x³ - \frac{1}{2}x² - \frac{5}{2}x²  + 2x³ =

# %% [markdown]
# ### Producto de un número por un monomio
#
# <font color="blue">
#
# Para multiplicar un número real por un monomio se multiplica el número por el coeficiente del monomio y se escribe la misma parte literal.
#
#
# Ejemplos
#
#     2 . 3x² = 6x²
#
#     −3⋅5x²y=−15x²y
#
# </font>

# %% [markdown]
# ### Producto de monomios
#
# <font color="blue">
#
# Para multiplicar cualquier par de monomios, se multiplican los coeficientes y las partes literales.
#
#
# Ejemplo
#
# Multiplica los monomios A(x, y) = −3x²y² y B(x, y) = 4x³y.
#
# $A(x, y) ⋅ B(x, y) = −3x^2y^2 ⋅ 4x^3y = (−3 ⋅ 4) x^2 ⋅ x^3 ⋅ y^2 ⋅ y = −12 x^{2 + 3} y^{2 + 1} = −12 x^5y^3 y^{2+1} = −12 x⁵y³$
#
# </font>

# %% [markdown]
# **Ficha1:** 2 Efectuar los siguientes productos y cocientes de monomios:
#
# a) 3x² · 4x³ =
#
# b) 2x³ · 4x³ · 3x³ =
#
# c) x³ · x³ =
#
# d) – 2x4· 3x³ =
#
# e) 7x · ( – 8x²) =
#
# f) ( – 3y²) · ( – 2y³) =
#
# g) 3x²y · 6xy³ =
#
# h) $\frac{3}{4}x² \cdot \frac{5}{2}x³$
#
# i) 4a3b2· a2b · 7ab=
#
# j) $- \frac{1}{2}a³ \cdot \frac {5}{3}a⁴ =
#
# k) 2a⁶ · 3a⁶· 2a⁶ =
#
# l) $\frac{2}{5}x³ \cdot (- \frac {3}{2}x) =$
#
# m) ab³ · (–3a²b) · 5a³b
#
# r) 15x⁴: (–3x)=
#
# s) $\frac{-14x⁷}{7x²}$
#
# u)  $\frac{5x⁷y³}{x²y}$
#
# w) $ \frac{-12a⁵b⁴c⁶}{2a³b²c}$
#
# y)  $\frac{3a⁵b \cdot (-12a⁴b²)}{4a³b²}$

# %% [markdown]
# **Fichas 1:** 3 Efectuar las siguientes operaciones combinadas con monomios:
#
# a) 15x⁵ – 3x³ · 4x² =
#
# b) 2x³ + 4x³ · 5x – 2x ·  ( – x2) =
#
# c) 3a · ab – 2a²· ( – 4b) – 8 · (2a²b)=
#
# d) 3x² + 4x2² – 2x²· ( – 3x) – [(4x³ + x2 – 2x · (x²)] =
#
# e) – 3xy² – ( – 4x · 7y²) + [8x²y³: (2xy)] =
#
# f) ( – y²) · ( – 2y²) – 5y · ( – 2y³) + 3y³ · ( – 4y) =
#
# g) (3x³· 6x – 2x²· x²) : (4x²· 3x² – 8x · x³) =
#
# h) a) $3x⁵ - \frac{4}{3}x² \cdot \frac{3}{2}x³$
#
# m) 2ab · ( – a³b) + [ab² · ( – 3a²b)] – 5a³b · ab + ab · a²b² =
#
# n) $2x² \cdot \frac{1}{3}x³ + \frac{21x⁷}{3x²}$

# %% [markdown]
# ### Potencia de un monomio
#
# <font color="blue">
#
# Para calcular la potencia de un monomio se eleva al exponente el coeficiente y cada una de las variables de la parte literal.
#
#
# Ejemplo
#
# Calcula [A(x, y)]³ siendo el monomio A(x, y) = −3x²y³.
#
# $[A(x, y)]³ = (−3x²y³)³ = (−3)³ ⋅ (x²)³ ⋅ (y³)³ = −27 ⋅ x^{2 \cdot 3} ⋅ y^{3 \cdot 3} = −27x^6y^9$
#
# </font>

# %% [markdown]
# 1.5 Realiza las operaciones
#
# a) 6x² + 2x² − x² + 3x² − x²
#
# b) 3x²y² − 2x²y² + 6²y² − x²2y²
#
# c) (−5ab) ⋅ (6abc)
#
# d) (−8x²y) ⋅ (−4xy² )
# e) (15xy) : (−3x)
# f) (2xyz) : (−2xy)

# %% [markdown]
# 1.6 Simplifica las siguientes expresiones.
#
# a) −2x³ − x² + 5x² − 6x + x − 2x² − 6x
#
# b) 5x − (x² + 3x³ ) + 3x² − x³ + 2x
#
# c) 11x⁷y³ + 4xy⁵ − 9x⁷y³ + xy⁵ − x²

# %% [markdown]
# 1.7 Calcula: − x²y − (−3x² ⋅ 7y) + (16x²y³z : 4y²z).

# %% [markdown]
# 1.8 Determina el grado, las variables y el término independiente
# de estos polinomios.
#
# a) P (x, y) = −2x⁵ − x²y² + 5x³ − 1 + 3x³ + 3
#
# b) Q (x, y) = x² + 4x³ − x − 9 + 4x⁴y³
#
# c) R (x, y) = x⁹ − x⁷y³ + y¹3 − 4
#
# d) S (x, y, z) = 7x²yz − 3xy²z + 8xyz²

# %% [markdown]
# 1.9 Reduce este polinomio y calcula su opuesto.
#
# R (x) = x⁵ + 1 − 3 + 4x⁵ − 3x − 2x

# %% [markdown]
#  ### Cociente de monomios

# %% [markdown]
# **Ficha 4:** 1. Efectuar  los  siguientes cocientes  en  los  que  intervienen monomios,  simplificar,  y  comprobar  el resultado:
#
# i) $(-18x³yz³) : (6xyz³)$
#
# j) $ [-3a \cdot (a³b) + 5a⁴b] : (-ab) = $    (Sol: -2a³)
#
# j) $ \frac{-3xy² \cdot (-2x³y)}{4x²y}= $    (Sol: 3x²y" / 2)

# %% [markdown]
# ## Polinomios. Operaciones con polinomios
# <font color="blue">
#
#
# Un polinomio es una expresión algebraica formada por la suma de varios monomios no semejantes, que se llaman términos.
#
# * El término principal es el monomio de mayor grado. Su coeficiente es el coeficiente principal.
# * El término independiente es el monomio que no tiene parte literal.
# * Se llama grado del polinomio al mayor de los grados de los monomios que lo forman.
#
# </font>

# %% [markdown]
# ### Valor numérico de polinomios

# %% [markdown]
# **Ficha 2:** 1. Hallar el valor numérico de cada polinomio para el valor indicado de la indeterminada:
#
# a) P ( x ) = x² + x + 1, para x = 2
# b) P ( x ) = x² + x + 1, para x = – 2
#
# c) P( x ) = 2x² – x + 2, para x = 3
#
# d) P( x ) = 2x² – x + 2, para x = – 2
# e) P ( x ) = – x²  – 3x + 4, para x = 4
#
# f) P ( x ) = – x²  + 3x + 4, para x = – 1
#
# g) P ( x ) = x³  + 3x² + 1, para x = 0
#
# h) P ( x ) = x³  – 4x² + x + 3, para x = –3
#
# i) P ( x ) = x⁴  – 4x² – 1, para x = 2
#
# j) P ( x ) = – x³  – 3x² – x + 2, para x = – 4
#
# i) $P(x)=x³ - \frac{4}{3}x² + \frac{5}{2}x -1                                \frac{619}{6}

# %% [markdown]
# **Ficha2:** 2 . Hallar el valor de K.
#
# a)  Dado P(x) = x² + 2x + k, hallar el valor de k para que P(2)=6
#
# b) Dado P(x) = x²– kx + 2, hallar el valor de k para que P( – 2)=8 (
#
# c) Dado P(x) = kx³– x²+ 5, hallar el valor de k para que P( – 1)=1

# %% [markdown]
# ### Suma y diferencia de polinomios
#
# <font color="blue">
#
#
# Para sumar o restar polinomios se suman o restan los monomios semejantes que los forman.
#
# Ejemplo
#
# Si P(x) = −3x² + 5x − 2 y Q(x) = 5x³ − x² − 3, calcula:
#
# * P(x) + Q(x) = −3x² + 5x − 2 + 5x³ − x² − 3 = 5x³ − 4x² + 5x − 5
#
# * P(x) − Q(x) = (−3x² + 5x − 2) − (5x³ − x² − 3) = −3x² + 5x − 2 − 5x³ + x² + 3 =
#                        = −5x³ − 2x² + 5x + 1
#
# </font>

# %% [markdown]
# **Ficha 2:** 3. Dados los siguientes polinomios:
#
# P(x) = 2x³ – 3x² + 4x – 2
#
# Q(x) = x⁴ – x³ + 3x² + 4
#
# R(x) = 3x² – 5x + 5
#
# S(x) = 3x – 2   Calcular.
#
# a) P(x) + Q(x) =                                                            (Sol: x⁴+x³+4x+2)
#
# b) P(x) + R(x) =                                          (Sol: 2x³–x+3)c) P(x) + S(x) = (Sol: 2x³–3x2+7x–4)
#
# d) S(x) + P(x) =                                          (Sol: ídem)e) P(x) + P(x) = (Sol: 4x³–6x²+8x–4)
#
# f) Q(x) – S(x) =                                          (Sol: x⁴–x³+3x²–3x+6)
#
# g) Q(x) + R(x) =                                          (Sol: x⁴–x³+6x²–5x+9)
#
# h) P(x) – R(x) =                                          (Sol: 2x³–6x²+9x–7)
#
# i) Q(x) + S(x) =                                          (Sol: x⁴–x³+3x²+3x+2)
#
# j) P(x) – S(x) =                                          (Sol: 2x³–3x²+x)
#
# k) S(x) – P(x) =                                          (Sol: –2x³+3x*2–x)
#
# l) P(x) – P(x) =                                           (Sol: 0)
#
# m) R(x)– S(x) =                                           (Sol: 3x²–8x+7)
#
# n) P(x) – Q(x) + R(x) =                                    (Sol: –x⁴+3x³–3x²–x–1)
#
# o) Q(x) – [R(x) + S(x)] =                                 (Sol: x⁴–x³+2x+1)
#
# p) S(x) – [R(x) – Q(x)]                                   (Sol: x⁴–x³+8x–3)

# %% [markdown]
# ### Producto de un número por un polinomio
#
# <font color="blue">
#
#
# Para multiplicar un número real por un polinomio, se multiplica dicho número por cada uno de los monomios que forman el polinomio.
#
# Ejemplo
#
# Dado el polinomio P(x, y) = 3x⁴ − 5xy, calcula:
#
# * 2P(x, y) = 2(3x⁴ − 5xy) = 6x⁴ − 10xy
# * $− \frac{3}{5}P(x,y)=− \frac{3}{5}(3x⁴−5xy)=− \frac{9}{5}x⁴+3xy$
#
#
# Ten en cuenta
#
# El producto también se puede escribir en la forma habitual de una multiplicación.
#
# <font>

# %% [markdown]
# ### Producto de polinomios

# %%
from IPython.display import Image
Image("/media/enri/Mi_Proyecto/Apoyo-3-ESO/Matemáticas 3º ESO/figuras/multiplicar_polinomios.jpg")

# %% [markdown]
# [link](https://drive.google.com/file/d/0B80bAhpAV1Y8bWZHUzU3dUpUaVk/view)
#
# Efectuar los siguientes productos:
#
# a) (3x²+5x-6) (8x²-3x+4)=
#
# b) (5x³-4x²+x-2) (x³-7x²+3)=
#
# c) (2x⁴-3x²+5x) (3x⁵-2x³+x-2)=
#
# d) (ab²+a²b+ab) (ab-ab²)=
#
# e) (-x⁶+x⁵-2x³+7) (x²-x+1)=
#
# f) (x²y²-2xy) (2xy+4)=

# %% [markdown]
# ### Productos de polinomios. Operaciones combinadas

# %% [markdown]
#  **Ficha 3:** 1. Efectuar   los   siguientes productos   en   los   que   intervienen monomios,   dando   el   resultado simplificado:
#
#  a) $(-2x³) \cdot (\frac{4}{5}x²) \cdot (\frac{1}{2})=$                                (Sol: $\frac{4}{5}x⁶)
#
#  b) $(- \frac{5}{7} \cdot (\frac{3}{}5}x³) \cdot (- \frac{4}{3} x)$                          (S0l: $\frac{4}{7}x¹0$ )
#
# c)  $5x³ - 3x²y \cdot (-4xz³) =$                                                        (Sol:  -60x⁶yz³)
#
# d) $-3ab² \cdot 2ab \cdot (-\frac{2}{3}a²b)=$                                         (Sol: 6x⁶-4x⁵+4x⁴+10x²)
#
# e) 2x² \cdot (3x⁴-2x³+2x²+5)=                                                         (Sol: 6x⁶-4x⁵+4x⁴+10x²)
#
# h) (-y⁴ + 2y³ -3y² + 2) \cdot (-2y²)=     (Sol: 2y⁶-4y⁵+6y⁴-4y²)

# %% [markdown]
# **Ficha 3:** 2 Dados los siguientes polinomios: P(x) = 2x³ – 3x² + 4x – 2
#
# Q(x) = x⁴ – x³ + 3x² + 4
#
# R(x) = 3x² – 5x + 5
#
# S(x) = 3x – 2
#
# Hallar los siguientes productos:
#
# a) P(x) · R(x) =              (Sol: 6x⁵–19x⁴+37x³–41x²+30x–10)
#
# b) P(x) · S(x) =              (Sol:         6x⁴–13x³+18x²–14x+4)
#
# c) S(x) · P(x) =                     (Sol: Ídem)
#
# d) P(x) · P(x) =             (Sol: 4x⁶–12x⁵+25x⁴–32x³+28x²–16x+4)
#
# e) Q(x) · S(x) =                   (Sol: 3x⁵–5x⁴+11x³–6x²+12x–8)
#
# f) [Q(x)]²=                  (Sol: x⁸–2x⁷+7x⁶–6x⁵+9x⁴–8x³+24x²+16)
#
# g) R(x) · S(x) =                   (Sol: 9x³–21x²+25x–10)h) [R(x)]

# %% [markdown]
# **Ficha 3:** 3. Realizar las siguientes operaciones combinadas de polinomios:
#
# a) (x³  + 2) ·[(4x² + 2) – (2x² + x + 1)]=   (Sol: 2x⁵–x⁴+x³+4x²–2x+2
#
# b) (x³  + 2) · (4x² + 2) – (2x² + x + 1)= (Sol: 4x⁵+2x³+6x²–x+3)
#
# c) (2x² + x – 2)(x² – 3x + 2) – (5x³ – 3x² + 4) = (Sol: 2x⁴–10x³+2x²+8x–8)
#
# d) (x² – 3x + 2) ·[(5x³ – 3x² + 4) – (2x² + x – 2)]= (Sol: 5x⁵–20x⁴+24x³–x²–20x+12)
#
# e) 2x² + x – 2– (x² – 3x + 2) · (5x³ – 3x² + 4) = (Sol: –5x⁵+18x⁴–19x³+4x²+13x–10
#
#
# **Ficha 3:** 4. Dados los polinomios del ejercicio 2, hallar las siguientes operaciones combinadas:
#
# a) [P(x) + Q(x)]· R(x) = (Sol: 3x⁶–2x⁵+17x³–14x²+10x+10)
#
# b) [Q(x) – R(x)]· S(x) = (Sol: 3x⁵–5x⁴+2x³+15x²–13x+2)
#
# c) [P(x) + Q(x) – S(x)]· R(x) = (Sol: 3x⁶–2x⁵+8x³+7x²–15x+20)
#
# d) [P(x) – Q(x)]·[R(x) + S(x)] = (Sol: –3x⁶+11x⁵–27x⁴+33x³–44x²+24x–18)
#
# e) P(x) + 2Q(x) = (Sol: 2x⁴+3x²+4x+6)
#
# f) P(x) – 3 [Q(x) + R(x)] = (Sol: –3x⁴+5x³–21x²+19x–29)
#
# g) P(x) – 2Q(x) + 3R(x) = (Sol: –2x⁴+4x³–11x+5)
#
# h) 2 P(x) · Q(x) – R(x) = (Sol: 4x⁷–10x⁶+26x⁵–30x4+44x3–39x²+37x–21)
#
# i) Q(x) · [2R(x) – 3S(x)] = (Sol: 6x⁶–25x⁵+53x⁴–73x³+72x²–76x+64)
#
# j) – [Q(x) + 2R(x)] · S(x) = (Sol: –3x⁵+5x⁴–29x³+48x²–62x+28)

# %% [markdown]
# ## Cocientes de polinomios

# %%
from IPython.display import Image
Image("/media/enri/Mi_Proyecto/Apoyo-3-ESO/Matemáticas 3º ESO/figuras/division_polinomios.jpg")

# %% [markdown]
# **Ficha 4:** 2 Efectuar (en el cuaderno) las siguientes divisiones de polinomios, y comprobar mediante la regla D=d·C+R:
#
# a) (x⁴-x³+7x²+x+15) : (x²+2)
#
# b) (2x⁵-x³+2x²-3x-3) : (2x²-3)
#
# c) ( 6x⁴–10x³+x²+11x–6) : (2x²-4x +3)
#
# d)  (x³+2x2+x–1) : (x²-1)
#
# e) (8x⁵–16x⁴+20x³–11x²+3x+2) : ( 2x²-3x+2)
# q)  (4x⁴–3x²+5x–7) : ( 2x²+x–3)
#
# t)   (4x⁴+2x³–3x²+5x–1) : (2x²-3)
#
# w) (6x⁶–2x⁵–11x⁴+3x³+18x²–5x–5) : (2x⁴–3x²+5)

# %% [markdown]
# **Ficha 4:** 3. Ídem con las siguientes divisiones en las que intervienen coeficientes fraccionarios:
#
# c)   (6x³–3x²+2x–5) : (3x-2)
#
# e)   (6x⁴+3x³–5x²+x–8) : (3x²-5x + 2)
#
# f)   (8x⁴–3x²+7x–5) : (4x²-3x+2)
#
# h)   (3x⁵–6x⁴–x³+10x²–8x+2) : (3x²-6x+1)

# %% [markdown]
# **Ficha 4:** 4. Dados los siguientes polinomios: P(x) = 9x⁵ – 21x⁴ + 27x³ + 4x + 37
#
# Q(x) = 9x² – 3x + 12       Hallar:
#
# a) Q(x) · Q(x) = (Sol: 81x⁴–54x³+225x²–72x+144)
#
# b )  P ( x )-3 x·Q ( x ) =
#
# c) P ( x ):Q ( x )
#
# d) Extraer el máximo factor común en Q(x)

# %% [markdown]
# ### Extracción de un factor común
#
# <font color="blue">
#
# Si los monomios de un polinomio tienen factores comunes, se puede expresar el polinomio como el producto de un monomio llamado factor común por otro polinomio de grado menor. Esta operación se llama extracción de factor común.
#
#
# Ejemplo
#
# Extrae factor común en el polinomio 3x⁴y² − 6x²y + 12x³y².
#
# El factor común es 3x²y, por tanto: 3x⁴y²−6x²y+12x³y²=3x²y(x²y−2+4xy)
#
# </font>

# %% [markdown]
# [link](https://drive.google.com/file/d/0B80bAhpAV1Y8bWZHUzU3dUpUaVk/view)
#
# 6 Extraer el máximo factor común posible:
#
# a) 4x²-6x+2x³
#
# b) 12x⁴y²+6x²y⁴-15x³y
#
# c) -3xy-2xy²-10x²yz
#
# d) -2x(x-3)2+4x²(x-3)
#
# e) -3x+6x²+12x³
#
# f) 2ab²-4a³b+8a⁴b³
#
# g) 2x³+4x²-8x
#
# h) 6x³y²-3x²yz+9xy³z²

# %% [markdown]
# 1.21 Saca factor común en los siguientes polinomios.
#
# a) 8x² − 4x
#
# b) 18x³ y² − 12x²y³
#
# c) 30a²b − 15ab² + 5a²b²
#
# d) −12ab³ + 4b² − 6b⁴
#
# e) 34a⁴ − 14a³b + 28ab³
#
# f) 20a⁴b²c + 36a²b − 18a³b²

# %% [markdown]
# 1.22 Saca factor común en estos polinomios.
#
# a) $\frac{x²}{2} - \frac{x}{2}$
#
# b) x ⋅ (xy²− y) + y² ⋅ (4xy − 3y)
#
# c) $\frac{x² - 2x}{7} - \frac{x² - x}{5}$

# %% [markdown]
# ## Identidades notables

# %% [markdown]
# ### Cuadrado de una suma
#
# <font color="blue">
#
# El cuadrado de una suma de dos términos es igual al cuadrado del primer término más el cuadrado del segundo término más el doble producto de los dos términos.
#
# $$(a+b)²=a²+b²+2ab$$
#
#
# Ejemplo
#
# Opera y simplifica la siguiente expresión.
#
# (2x+3x²)2=(2x)²+(3x²)2+2⋅2x⋅3x²=4x²+9x⁴+12x³=9x⁴+12x³+4x²
#
# </font>

# %% [markdown]
# ### Cuadrado de una diferencia
#
# <font color="blue">
#
# El cuadrado de una diferencia de dos términos es igual al cuadrado del primer término más el cuadrado del segundo término menos el doble producto de los dos términos.
#
# $$(a−b)²=a²+b²−2ab$$
#
#
# Ejemplo
#
# Desarrolla la siguiente identidad notable.
#
# $(\frac{1}{2}x−x²)²=(\frac{1}{2}x)² + (x²)² − 2 \cdot \frac{1}{2}x \cdot x² = \frac{1}{4} x² +x⁴ − x³ = x⁴ − x³+ \frac{1}{4}x²$
#
# </font>

# %% [markdown]
# ### Suma por diferencia
#
# <font color="blue">
#
# El producto de la suma de dos términos por su diferencia es igual al cuadrado del primer término menos el cuadrado del segundo término.
#
# (a+b)(a−b) = a²−b²
#
# Ejemplo
#
# Calcula y simplifica.
#
# $(\frac{2}{3} x + \frac{1}{2} x²)(\frac{2}{3} x − \frac{1}{2} x²) = (\frac{2}{3} x)² − (\frac{1}{2} x²)² = \frac{4}{9} x² − \frac{1}{4} x⁴ = − \frac{1}{4}x⁴ + \frac{4}{9}x²$
#
# </font>

# %% [markdown]
# 1.24 Desarrolla los siguientes cuadrados
#
# a) (x+7)²
#
# b) (2a+1)²
#
# c) (6+x)²
#
# d) (3a²+2b)²
#
# e) (x-4)²
#
# f) (3a-b)²
#
# g) (5-x)²
#
# h) (2b²-5b³)²

# %% [markdown]
# 1.25 Desarrolla
#
# a) (3x³-a²)2
#
# b) (x²+x³)2
#
# c) (2x+x³)²
#
# d) (6ab²-2y)2

# %% [markdown]
# 1.26 Expresa como cuadrado de una suma o una diferencia, según convenga.
#
# a) x² + 6x + 9
#
# b) 4x² − 12xy + 9y²
#
# c) x² + 4xy + 4y²
#
# d) x⁴ + 2x² + 1

# %% [markdown]
# 1.27 Calcula los siguientes productos.
#
# a) (x + 7) ⋅ (x − 7)
#
# b) (7x + 4y) ⋅ (7x − 4y)

# %% [markdown]
#  1.28 Estudia si estas expresiones se pueden expresar como suma por diferencia.
#
# a) x² − 1
#
# b) x⁴ − 9
#
# a) (x + 1) ⋅ (x − 1)
#
# c) 16 − x²

# %% [markdown]
# 1.29 Expresa en forma de producto.
#
# a) 4x² − 4x + 1
#
# b) 9a²2 − 30ab + 25b²
#
# c) 100x² − 4z⁶

# %% [markdown]
# ## Varios

# %% [markdown]
# 1.31 Simplifica las fracciones algebraicas.
#
# a) $\quad \frac{x³}{xy}    $
#
# a) $\quad   \frac{5x³y²}{3xy}  $
#
# a) $\quad  \frac{6x²y}{3x²y²}   $
#
# a) $\quad   \frac{4x²y}{4xy}  $

# %% [markdown]
# 1.11 Calcula el valor numérico del polinomio en cada caso.
#
# a) P (x) = 3x⁶ + 2x⁵ − 3x⁴ - x² + 7x -2 para x = 0
#
# b) P (x, y) = − x⁴y − x²y + 7xy − 2, para x = 1, y = 2.

# %% [markdown]
# 1.12 Dados los polinomios:
#
# P (x, y) = 3x²y + xy − 7x + y − 2
#
# Q (x, y) = − xy² + 4y² − 3x
#
# halla los valores numéricos:
#
# P (0, 0)   P (1, 1)   Q (0, −1)   Q (0, 2)

# %% [markdown]
# 1.13 Reduce los siguientes polinomios y calcula su valor numérico para x = 2.
#
# a) P (x) = 4 − 3x² + x − x² + 1
#
# b) Q (x) = x⁴ − 4 − 3x² + x − x² + 1 − 3x⁴ − 3x

# %% [markdown]
# 1.14 Un número es raíz de un polinomio cuando el valor numérico del polinomio
# para dicho número es cero. Determina si los números −4 y 4 son raíces
# de este polinomio.
#
# P (x) = x² − 5x + 4
#
# ¿Sabrías hallar otra raíz del polinomio?

# %% [markdown]
# 1.15 Halla la suma, resta y producto de cada par de polinomios.
#
# a) R (x) = x⁴ − x + 1; S (x) = x² + 1
#
# b) R (x) = x + 1; S (x) = x² + x − 1
#
# c) R (x) = 5x⁷ − x⁸ + 1; S (x) = x² + x⁶ − 1
#
# d) R (x) = x⁵ − x⁴ + x³ + 2x + 1; S (x) = x³ + 2x
#
# e) R (x) = 7x³ + 2x² + x − 3; S (x) = x⁴ + x² − 8
#
# f) R (x) = x⁷ + 3; S (x) = x³ + x² + 4x + 2

# %% [markdown]
# 1.16 Calcula − A(x) + B(x)y − A(x) − B(x) con los polinomios:
#
# A(x) = 3x⁴ − 5x³ + x² − 7
#
# B(x) = −3x⁴ + x³ − 2x + 1

# %% [markdown]
# 1.17 Calcula el producto de los dos polinomios del ejercicio anterior, utilizandola propiedad distributiva.

# %% [markdown]
# 1.18 Calcula
#
# a) (x³ − 3x² + 2x) : x
#
# b) (2x³ − 3x² − 5x − 5) : (x − 2)
#
# c) (2x³ − 3x² + 4x − 3) : (x² + x − 1)
#
# d) (x⁴ + x³ − x² + x + 1) : (x³ − 5)
#
# e) (−6x⁵ + x³ + 2x + 2) : (4x³ + 2x + 3)
#
# f) (x⁸ − 1) : (x⁵ + x³ + x + 2)
#
# g) (x − 1) : x
#
# h) (x² − 1) : (x + 1)
#
# i) (x² − 5x + 6) : (x − 2)

# %%
from IPython.display import Image
Image("/media/enri/Mi_Proyecto/Apoyo-3-ESO/Matemáticas 3º ESO/figuras/division_polinomios.jpg")

# %% [markdown]
# 1.19 Haz las siguientes divisiones y comprueba que están bien realizadas.
#
# a) (x³ − 4x² + 5x − 2) : (x² − 2)
#
# b) (x⁴ + x² + 3) : (x³ + 3x² + 2x + 6)

# %% [markdown]
# 1.20

# %% [markdown]
# 1.32 Simplifica
#
# a) $\quad   \frac{x²-4x+4}{x-2}  $
#
# a) $\quad   \frac{x²-9}{2x-6}  $

# %% [markdown]
# 1.33 Calcular **a**, para que a) $\quad \frac{x²-4ax+a²}{2x+3} = 2x+3$

# %% [markdown]
# 1.34 Indica si las siguientes expresiones son o no monomios.
#
# a) 2x² + yz
#
# b) $\quad \frac{2x*2y^{− 4}}{11}
#
# c) 5x⁵y²
#
# d) $\quad \sqrt{xyz}
#
# e) $\quad \frac{3}{2}x + \frac{1}{3}y$
#
# f) 3ab + 2a²

# %% [markdown]
# 1.35 Di si los monomios son semejantes.
#
# a) xz, 3xy, −6xy
#
# b) ab, a²b, 7b
#
# c) 4c⁹d, c⁷d, cd⁴
#
# d) 8xy² , 7xy

# %% [markdown]
# 1.36 Realiza estas sumas de monomios.
#
# a) xz + 3xz + 6xz
#
# b) a²b + 9a²b + 27a²b
#
# c) 9c⁹ + c⁹ + c⁹
#
# d) 8xy + 7xy + 43xy + 23xy

# %% [markdown]
# 1.37 Efectúa las siguientes restas de monomios.
#
# a) 3xz − 6xz
#
# b) 9a*2b − 2a²b
#
# c) 18xy − 7xy − 3xy − 3xy
#
# d) 5x⁹9 − x⁹ − x⁹ − x⁹

# %% [markdown]
# 1.39 Realiza las operaciones e indica el grado del monomio resultante.
#
# a) 2x² + 3x² − 7x² + 8x² − x²
#
# b) 5xy³ − 2xy³ + 7xy³ − 3xy³ + 12xy³
#
# c) 3abc − 2abc + 6abc + 9abc − 4ab
#
# d) 5xz − 3xz + 15xz − 11xz + 8xz − 3xz
#
# e) (2xyz) ⋅ (2x²yz³ )
#
# f) (−2abc) ⋅ (3a²b²c²) ⋅ (− bc)
#
# g) 7x ⋅ (2xy) ⋅ (−3xy 5 ) ⋅ (xy)
#
# h) (6ac³ ) ⋅ (−2a²c³ ) ⋅ (−3ac) ⋅ (−4a³c² )
#
# i) (21x²y³ ) : (7xy² )
#
# j) (9abc) : (3bc)
#
# k) (16x⁴y⁵a³b⁶) : (8x²y³a²b⁵ )
#
# l) (5m³n²g⁴ ) : (2mng)

# %% [markdown]
# 1.39 Haz las siguientes operaciones.
#
# a) − xz + 6xz + xyz − 8xz
#
# b) 9a²b − 2a²b + 8a²b − a²b
#
# c) 9c⁹ − c⁹ − c⁹ + 10c⁹
#
# d) 8xy + 7xy − xy + 3xy − xy

# %% [markdown]
# 1.40 Realiza estas multiplicaciones.
#
# a) − xz + 6xz + xyz − 8xz
#
# b) 9a²b − 2a²b + 8a²b − a²b
#
# c) 9c⁹ − c⁹ − c⁹ + 10c⁹
#
# d) 8xy + 7xy − xy + 3xy − xy

# %% [markdown]
# 1.41 Efectúa las siguientes divisiones de monomios.
#
# a) 9xy : 3xy
#
# b) 9ab : ab
#
# c) 15x⁸ : 5x⁸
#
# d) 8xy² : 2xy²
#
# e) 15x⁹ : 3x⁹
#
# f) 32x⁷ : 8x⁴

# %% [markdown]
# 1.42 Calcula y simplifica el resultado todo lo que puedas.
#
# a) 2x² − 5(− x² ) + 8x² − (2x) ⋅ (3x)
#
# b) 2x ⋅ (− y) + 7xy − yx + (−4x) ⋅ (−5y)
#
# c) 3x² − (− x)² + 3(− x² ) + (−3) ⋅ (− x)²
#
# d) (2xy − 3xy + 7xy) ⋅ (2ab)
#
# e) (x² − 3x² + 6x² − 2x² ) ⋅ (−5zx)

# %% [markdown]
# 1.43

# %% [markdown]
# 1.44 Indica el grado, el término independiente y el polinomio opuesto de los polinomios.
#
# a) P (x) = − x³ + x² − 7x − 2
#
# b) Q (x) = − x² + 2x + 6
#
# c) R (x) = x + 1
#
# d) S (x) = 8
#
# e) T (x) = 12x − x² + x⁴
#
# f) $ \quad ( x ) =  \frac{1}{2} x² - x- \frac{1}{6}$

# %% [markdown]
# 11.46 Reduce los siguientes polinomios.
#
# a) P (x) = − x² − x − 2 − x³ + x 2 − x − 2
#
# b) Q (x) = − x² + x² + 6 − x + x² − 7x − 2
#
# c) R (x) = x + 1 − x + x²
#
# d) S (x) = 8 − x + 34 − x + 324
#
# e) T (x) = x⁴ + x⁴ − x³ + x²2 − 7x − 2
#
# f) $\quad \frac{1}{2}x² - x - \frac{1}{6} - \frac{2}{7}x²$

# %% [markdown]
# 11.47 Calcula el valor numérico de cada polinomio para los valores de la variable.
#
# a) A (x) = x + 1, para x = 1
#
# b) B (x) = x⁴ + 3, para x = 2
#
# c) C (x) = 4x⁵ − x²2 + 3, para x = −1
#
# d) D (x) = −9x⁴ + 7x² + 5, para x = 1
#
# e) E (x) = x³ + x² + x + 2, para x = −2
#
# f) F (x) = x⁴ + x⁴ − x³ + x² − 7x − 2, para x = 0
#
# g) G (x) = −14, para x = −2

# %% [markdown]
# 1.48 Halla los valores numéricos para el polinomio:
#
# P (x, y) = 2x 2 y + xy 2 − 3xy + 5x − 6y + 9
#
# a) P (0, 0)
#
# b) P (1, 1)
#
# c) P (−1, 1)
#
# d) P (1, −1)
#
# e) P (1, 2)
#
# f) P (2, 1)

# %% [markdown]
# <font color = "blue">
#
# ¿CÓMO SE CALCULA EL COEFICIENTE DE UN POLINOMIO CONOCIENDO
# UNO DE SUS VALORES NUMÉRICOS ?
#
# Calcula el valor de k en el polinomio P(x) = x² − x + k, si P(2) = 5.
#
# PRIMERO . Se sustituye, en el polinomio, la variable por su valor.
#
# P ( 2 ) = 2² − 2 + k = 5
#
# SEGUNDO . Se despeja k en la ecuación resultante.
#
# 4-2+k = 5
#
# k = 5-4+2 = 3
#
# </font>

# %% [markdown]
# 1.50 Calcula el valor de k en cada polinomio, sabiendo que P(1) = 6.
#
# a) P (x) = kx⁷ + x³ + 3x + 1
#
# b) P (x) = kx + kx + 4
#
# c) P (x) = 9x⁵ + kx² + kx − k
#
# d) P (x)= kx⁶ − kx³ + kx + k
#
# e) P (x) = k

# %% [markdown]
# 1.51 Dados los polinomios:
#
# P (x) = 2x⁵ − 3x⁴ + 7x³ − 2x² + 3x − 6
#
# Q (x) = 3x⁴ − 2x³ + 5x² − 7x − 1
#
#
# R (x) = 3x² − x + 1
#
# S (x) = 2x + 3
#
#
# calcula.
#
# a) P (x) + Q (x)
#
# b) Q (x) + P (x)
#
# c) P (x) − S (x)
#
# d) Q (x) − P (x)
#
# e) P (x) + R (x)
#
#
# f) R (x) + S (x)
#
# g) Q (x) − R (x)
#
# h) R (x) − P (x)

# %% [markdown]
# 1.52 Suma y resta los siguientes polinomios.
#
# a) P (x) = −7x + 4; Q (x) = 2x + 5
#
# b) P (x) = −3x² + 1; Q (x) = − x² + 2x
#
# c) P (x) = −3x² + 1; Q (x) = − x² + 2x + 6
#
# d) P (x) = −5x³ + x² − 7x − 2; Q (x) = 5x³ + x² + 4x − 2
#
# e) $\quad \frac{1}{2}x² - 2xy - \frac{3}{2} y² \; ; \; Q(x) = x²-xy-y²$
#
# f) $P (x) = \frac{1}{2}x² −2xy − \frac{3}{2}y² ; Q (x) = \frac{1}{33}x² − 2xy − \frac{2}{3}y²$
#
# g) $P (x) =  x² - \frac{1}{2}x -3; Q (x) = − \frac{1}{2}x² + \frac{1}{3}x − 1$
#
# h) $P (x) = x² − 5x − 3; Q (x) = − \frac{1}{2}x² + \frac{1}{3}$

# %% [markdown]
# 1.53 Dados los polinomios:
#
# P (x) = 2x 5 − 3x 4 + 7x 3 − 2x 2 + 3x − 6
#
# Q (x) = 3x − 2x + 5x − 7x − 1
#
# R (x) = 3x 2 − x + 1
#
# S (x) = 2x + 3
#
# calcula.
#
# a) P (x) + Q (x) + R (x) + S (x)
# c) [P (x) + Q (x)] − [R (x) + Q (x)]
# b) P (x) − R (x) + S (x) − Q (x)
# d) [P (x) − Q (x)] − [R (x) − Q (x)]

# %% [markdown]
# 1.54 Halla cuál es el polinomio Q (x) que hay que sumar a P (x) = x 2 + 2x − 1  para obtener como resultado R (x).
#
# a) R (x) = x − 1
#
# b) R (x) = 2x² − x − 6
#
# c) R (x) = 5x² − x + 1
#
# d) R (x) = −7x² − 3x
#
# e) R (x) = x³ − x
#
# f) R (x) = x³ − x²

# %% [markdown]
# 1.55  Dados los polinomios:
#
# P (x) = 2x⁶ − 7x⁴ + 2x³ − 2x² + x − 1
#
# Q (x) = 3x⁵ − 2x³ + x² − x − 1
#
# R (x) = x² − x + 1
#
# calcula.
#
# a) P (x) ⋅ Q (x)
# b) Q (x) ⋅ R (x)
# c) P (x) ⋅ R (x)
# d) R (x) ⋅ R (x)

# %% [markdown]
# 1.56 Dados los polinomios:
#
# P (x) = 2x⁵ − 3x⁴ + 7x³ − 2x² + 3x − 6
#
# Q (x) = 3x⁴ − 2x³ + 5x² − 7x − 1
#
# R (x) = 3x² − x + 1
#
# S (x) = 2x + 3
#
# calcula.
#
# a) [P (x) − Q (x)] ⋅ S (x)
#
# b) [R (x) − Q (x)] ⋅ S(x)
#
# c) [P (x) + Q (x) + R (x)] ⋅ S (x)
# 1.57 Realiza las siguientes operaciones
# d) [P (x) + Q (x) − R (x)] ⋅ S (x)

# %% [markdown]
# 1.57 Realiza las siguientes operaciones
#
# a) $\quad \left ( \frac{1}{2}x² + \frac{3}{4}x \right ) - \left (\frac{5}{4}x +7  \right ) + \left ( \frac{7}{2}x²- \frac{9}{4}x+3 \right )$
#
# b) $\quad \left ( \frac{5}{3}x³ - \frac{2}{5}x²+x-7 \right ) \cdot \left ( \frac{5}{2}x²-3x \right )$
#
# c) $\quad \frac{2}{5}x² \cdot (x³-3x²+x-1)-x³ \cdot     \left (  \frac{1}{2}x² - x + \frac{2}{3}\right ) $
#
#
# d) $\quad \frac{5}{6}x \cdot (x⁵-x²+3x-1)-x⁵ \cdot \left ( \frac{1}{3}x² - \frac{5}{2}x + \frac{4}{3} \right ) $

# %% [markdown]
# 1.58 División
#
# a) (4x⁴ + 3x³ − 5x² + x + 7) : (x − 1)
#
# b) (4x⁴ − 2x³ + 3x² − 2x + 5) : (x + 1)
#
# c) (7x⁵ + 4x⁴ + 3x³ − 5x² + 2x − 1) : (x² + x)
#
# d) (x⁴ − 2x³ + x² − x + 3) : (x² + x + 1)
#
# e) (4x⁴ − 2x³ + 7x² − 2x + 3) : (x² − x − 2)

# %% [markdown]
# 1.59 Desarrolla.
#
# a) (3x + 2)²
#
# b) (3x − 2)²
#
# c) (3x 2 − 2x)²
#
# d) (7x 3 + 4x 2 )²
#
# e) (2x + 7) ⋅ (2x − 7)
#
# f) (2x² + 3x) ⋅ (2x² − 3x)
#
# g) (x⁴ + 3x⁵ ) ⋅ (x⁴ − 3x⁵ )
#
#
# h)  $\quad (2x - \frac{1}{2})²$

# %% [markdown]
# 1.60 Desarrolla estos cuadrados.
#
# a) (x + 5)²
#
# b) (2y − 7)²
#
# c) (− y − 8)²
#
# d) (xy − 6x)²
#
# e) (− x − y)²
#
# f) (x + 2xy)²

# %% [markdown]
# 1.61

# %% [markdown]
# <font color = "blue">
#
# Realiza la siguiente operación.
#
# (2x − 3)² − (2 + x)²
#
# Se desarrolla el polinomio aplicando los resultados de las igualdades notables.
#
# (2x − 3)² − (2 + x)² = (4x² − 12x + 9) − (4 + 4x + x² )
#
# PRIMERO. Se quitan los paréntesis, teniendo en cuenta los signos.
#
# (4x² − 12x + 9) − (4 + 4x + x² ) = 4x² − 12x + 9 − 4 − 4x − x²
#
# SEGUNDO. Se reduce el polinomio.
#
# 4x² − 12x + 9 − 4 − 4x − x² = 3x² − 16x + 5
#
# Por tanto: (2x − 3)² − (2 + x)² = 3x² − 16x + 5.
#
# </font>

# %% [markdown]
# 1.63 Desarrolla y simplifica las siguientes expresiones.
#
# a) 5x² + (2x² + 1) 2 − 2x⁴ − (x − 1)²
#
# b) (x − 1)² − (x² + x + 1)
#
# c) (5x + 5) 2 − (5x − 5)²
#
# d) (2x³ − 3x² )² − (2x + 2) ⋅ (2x − 2)
#
# e) (x + 6)² − (x − 6)² − (x − 5) ⋅ (x + 5)
#
# f) (2x + 1)² − (2x − 1)² + (2x + 1) ⋅ (3x + 2)

# %% [markdown]
# 1.64 Expresa estos polinomios como el cuadrado de una suma o diferencia.
#
# a) 9x² + 18x + 9
#
# b) 16x² − 16x + 4
#
# c) x²2 + 16x + 64
#
# d) 4x² + 4x + 1

# %% [markdown]
# 1.64 Expresa el área de cada figura mediante un polinomio. Simplifica su expresión.

# %%
from IPython.display import Image
Image("/media/enri/Mi_Proyecto/Apoyo-3-ESO/Matemáticas 3º ESO/figuras/polinomio_areafiguras.jpg")

# %% [markdown]
# 1.66 Escribe los polinomios como producto de dos factores.
#
# a) x² − 16
#
# b) x⁴ − 36
#
# c) 4x² − 25
#
# d) x² − 4x + 4
#
# e) 16x² − 24xy + 9y²
#
# f) 16x² + 24x² + 9

# %% [markdown]
# 1.67

# %% [markdown]
# 1.68 Extrae factor común en estas expresiones.
#
# a) 3x² − 4x
#
# b) (x + 1) + 3(x + 1)
#
# c) xy − 6xyz − 5xyzt
#
# d) 3x − 4x² − 6x³

# %% [markdown]
# <font color = "blue">
#
# ¿CÓMO SE SIMPLIFICAN FRACCIONES ALGEBRAICAS ?
#
# Simplifica.
#
# ( y⁴ − y³ ) ⋅ ( x² − 2x + 1 )
#
# xy² ( x − 1 )
#
# PRIMERO .
#
# Se descomponen el numerador y el denominador en tantos factores
# como sea posible.
#
#
#
#
#
#
# </font>

# %%
from IPython.display import Image
Image("/media/enri/Mi_Proyecto/Apoyo-3-ESO/Matemáticas 3º ESO/figuras/simplificar_fracciones.jpg")

# %% [markdown]
# 1.69 Simplifica estas expresiones aplicando las igualdades notables y extrayendo factor común.
#
# a) 7x² − 14x + 7
#
# b) 16x² + 64x + 64
#
# c) x 3 − 2x² + x
#
# d) 18x⁴ − 12x² + 2
#
# e) (2x + 4) ⋅ (x − 2)
#
# f) (x − 5) ⋅ (x² + 5x)
# 1.71
# g) (− x − 7) ⋅ (x − 7)
#
# h) (− x² + 5) ⋅ (− x² − 5)

# %% [markdown]
# 1.71 Simplifica las fracciones algebraicas.
#
# a) $\quad \frac{x² + 2x + 1}{x ( x + 1 )}$
#
# b) $ \quad \frac{x² ( x² − 4 )}{x ( x − 2 )}$
#
# c) $\quad \frac{y² ( x² − 4 x + 4 )}{x ( x − 2 )} $
#
# d) $\quad \frac{( x² − 9 )( y² − 16 )}{xy ( 2x − 6 )( y + 4 ) 2}$

# %% [markdown]
# # 1.72 Simplifica las siguientes fracciones algebraicas
#
# a) $\quad \frac{x³ ( x² − 16 )}{x ( x + 4 )} $
#
# b) $\quad \frac{x ( 2x² − 16 x + 32 )}{( x² − 16 )} $
#
#
# c) $\quad \frac{18 x⁴ − 36 x² + 18}{9 x² ( x − 1 )²} $
#
#
# d) $\quad \frac{( 3 x − 2 )²}{9 x² − 4} $
#
#
# e) $\quad \frac{( 6 x + 8 )²}{27 x² − 48} $
#
#
# f) $\quad \frac{( 3 x + 12 )( x − 4 )}{2 x² − 32} $

# %% [markdown]
# 1.73

# %% [markdown]
# 1.74

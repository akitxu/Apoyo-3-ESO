# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Números" data-toc-modified-id="Números-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Números</a></span></li><li><span><a href="#Geometría" data-toc-modified-id="Geometría-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Geometría</a></span></li><li><span><a href="#Funciones" data-toc-modified-id="Funciones-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Funciones</a></span></li></ul></div>

# %% [markdown]
# [Adaptado de](https://www.alfonsogonzalez.es/asignaturas/3_eso/ejercicios_3_eso_propuestos.php)

# %% [markdown]
# ## Números

# %% [markdown]
# **001 Halla seis múltiplos de cada número.**
#
#     a) 5
#
#     b) 10
#
#     c) 50
#
#     d) 72

# %% [markdown]
# **002 Obtén dos divisores de los siguientes números.**
#
#  <font color ="blue">Ejemplo: Divisor de 350. $\left ( 350 = 2 \cdot 5^2 \cdot 7 \right )$.  Un divisor podría ser. $7 \times 2 = 14$</font>
#
#     a) 25
#
#     b) 15
#
#     c) 150
#
#     d) 190
#
#     e) 320
#
#     f) 450
#
#     g) 600
#
#     h) 725

# %% [markdown]
# **003 Completa los huecos con la palabra adecuada (múltiplo o divisor).**
#
# a) 24 es .......... de 6
#
# c) 125 es .......... de 25
#
# b) 12 es .......... de 24
#
# d) 51 es .......... de 17

# %% [markdown]
# **004 Averigua cuáles de los siguientes números son primos o compuestos:
# 79, 93, 117, 239, 313, 585, 1.001 y 6.723.**
#
# **Primos :** ------------------------
#
# **Compuestos:** --------------------------

# %% [markdown]
# **005** Busca los números primos comprendidos entre 100 y 120.

# %% [markdown]
# **006** Completa los huecos.
#
# a) Div (30) = {1, 2, 3,-- ,-- ,-- , 15,-- }
#
# b) Div (100) = {1, 2,-- ,-- , 10,-- , 25,-- , 100}
#
# c) Div (97) = {--, 97}
#
# d) Div (48) = {--, 2, 3, 4, 6,-- ,-- ,-- ,-- ,-- }

# %% [markdown]
# **007 Obtén el m.c.d. de cada pareja de números.**
#
# a) 6 y 14   m.c.d. = -------
#
# b) 9 y 10   m.c.d. = -------
#
# c) 5 y 15   m.c.d. = -------
#
# d) 42 y 4   m.c.d. = -------
#
# e) 76 y 85  m.c.d. = -------
#
# f)102 y 104 m.c.d. = -------
#
# g) 160 y 180 m.c.d. = -------
#
# h) 281 y 354 m.c.d. = -------

# %% [markdown]
# **008 Obtén el m.c.m. de estos números.**
#
# a) 7 y 14       m.c.m. = ----
#
# b) 12 y 7       m.c.m. = ----
#
# c) 9 y 16       m.c.m. = ----
#
# d) 8 y 25       m.c.m. = ----
#
# e) 61 y 49      m.c.m. = ----
#
# f) 280 y 416    m.c.m. = ----
#
# g) 150 y 415    m.c.m. = ----
#
# h) 296 y 432    m.c.m. = ----

# %% [markdown]
# **009 Obtén el m.c.d. y el m.c.m. de cada grupo de números.**
#
# a) 25, 50 y 100       m.c.d = ----- y m.c.m = ------
#
# b) 6, 7 y 8           m.c.d = ----- y m.c.m = ------
#
# c) 40, 42 y 48        m.c.d = ----- y m.c.m = ------
#
# d) 12, 18 y 20        m.c.d = ----- y m.c.m = ------
#
# e) 8, 10, 12 y 14     m.c.d = ----- y m.c.m = ------
#
# f) 2, 4, 6, 8 y 10    m.c.d = ----- y m.c.m = ------

# %% [markdown]
# **010 Dos buques mercantes salen de un puerto el día 1 de enero. El primero tarda en regresar 26 días, y el segundo, 30 días. Ambos van y vienen constantemente. ¿Cuántos días tardan los buques en coincidir de nuevo en el puerto?**
#
# Los barcos tardan ---- días en volver a coincidir en el puerto

# %% [markdown]
# **011 Se dispone de dos rollos de cuerda que tienen 144 y 120 m de longitud,
# respectivamente. ¿Cuál es el número de trozos iguales, de tamaño máximo,
# que se puede hacer con los rollos de cuerda?**

# %% [markdown]
# **012 Escribe todos los números enteros.**
#
# <font color ="red">Ejemplo: Números enteros mayores que −2 y menores que +3. Respuesta:   -3 < -2 < -1 < 0 < 1 < 2 < 3</font>
#
# a) Mayores que −4 y menores que +2. Respuesta:
#
# b) Menores que +3 y mayores que −5. Respuesta:
#
# c) Menores que +1 y mayores que −2. Respuesta:
#
# d) Mayores que −5 y menores que +6. Respuesta:

# %% [markdown]
# **013 Representa en la recta numérica los siguientes números: −6, 0, −8, +3, −5 y +4.**

# %% [markdown]
# **014 Indica el número entero que corresponde a cada punto marcado en la recta numérica.**
#
#  ![014_Repaso.JPG](attachment:014_Repaso.JPG)
#
# a) A = --, B = --, C = --, D = --
# b) A = --, B = --, C = --, D = --

# %% [markdown]
# **015 Completa con números enteros.**
#
# a) −3 < -- < -- < +1
#
# b) +3 >  >  > −1
#
# c) −9 <--  < -- < −6
#
# d) −15 <--  < -- < −10
#
# ¿Puedes colocar más de un número en cada hueco?

# %% [markdown]
# **016 Calcula.**
#
# a) ⏐+3⏐
#
# b) ⏐−3⏐ =
#
# c) ⏐−7⏐ =
#
# d) ⏐−4⏐ =
#
# e) ⏐+5⏐ =
#
# f) ⏐−9⏐=

# %% [markdown]
# **017 Obtén los opuestos de estos números.**
#
# a)  Op(-5) = ---
#
# b)  Op(+8) = ---
#
# c) − Op(-15) = ---
#
# d)  Op(-40) = ---
#
# e)  Op(+125) = ---
#
# f)  Op(-134) = ---

# %% [markdown]
# **018 Calcula.**
#
# a) (−11) + (+4) = --
#
# b) (+13) + (+12) = --
#
# c) (−20) + (−12) = --
#
# d) (+11) + (−15) = --

# %% [markdown]
# **019 Realiza estas restas.**
#
# a) (−5) − (+5) = --
#
# b) (+3) − (−7) = --
#
# c) (−15) − (−17) = --
#
# d) (+8) − (+7) = --

# %% [markdown]
# **020 Calcula.**
#
# a) (−4) + (+5) − (−18) = --
#
# b) (+30) − (+7) + (−18) = --
#
# c) (+20) − (−5) − (+5) = --
#
# d) (−12) − (+3) − (−7) = --

# %% [markdown]
# **021 Completa los huecos para que las igualdades sean ciertas.**
#
# a) (+13) + ** = (+12)
#
# b) ** + (−20) = (−12)
#
# c) (−15) − ** = (+9)
#
# d) ** − (+8) = (+7)

# %% [markdown]
# **022 Calcula.**
#
# a) (+4) ⋅ (−5) = ***
#
# b) (−40) ⋅ (+8) = ***
#
# c) (−40) ⋅ (−10) = ***
#
# d) (+2) ⋅ (+15) = ***

# %% [markdown]
# **023 Haz estas divisiones.**
#
# a) (+35) : (−7) = ***
#
# b) (−21) : (+3) = ***
#
# c) (−18) : (−2) = ***
#
# d) (+40) : (−10) = ***

# %% [markdown]
# **024 Completa los huecos para que las igualdades sean ciertas.**
#
# a) (+13) ⋅ ** = (+39)
#
# b)  **⋅ (−6) = (−42)
#
# c) (−15) : ** = (+5)
#
# d) ** : (+8) = (+2)

# %% [markdown]
# ** 025 Realiza estas operaciones.
# a) 6 + (−4 + 2) − (−3 − 1) = ***
#
# b) 7 − (4 − 3) + (−1 − 2) = ***
#
# c) 3 + (2 − 3) − (1 − 5 − 7) = ***
#
# d) −8 + (1 + 4) + (−7 − 9) = ***
#
# e) 10 − (8 − 7) + (−9 − 3) = ***
#
# f) 1 − (2 − 3) + (−4 − 5) = ***
#
# g) −1 − (−1 + 2 − 5 + 4) = ***
#
# h) 3 + (5 − 9) − (7 − 5 − 7) = ***

# %% [markdown]
# **026 Halla el valor de estas expresiones.**
#
# a) 8 + 7 − 6 + 5 − 11 + 2  = **
#
# b) (−12) ⋅ 7 : 3   = **
#
# c) 9 − 12 : 4   = **
#
# d) 100 − 22 ⋅ 5  = **
#
# e) (−26) : 2 − 6 : 3 + 4  = **
#
# f) 15 ⋅ (−9) − 7 ⋅ (−6) : 2  = **

# %% [markdown]
# **027 Haz estas operaciones.**
#
# a) (−4) − (−6) : (+3) = ***
#
# b) (+5) : (−5) − (−7) ⋅ (+2) = ***
#
# c) (−11) − (+3) ⋅ (−4) : (−6) − (−9) = ***
#
# d) (−18) − [(+4) + (−6)] : (+2) + (+5) = ***
#
# e) (−5) − (−9) − (+4) ⋅ (−3) : (−2) : (−6) = ***
#
# f) (+3) − (+6) : (+2) ⋅ (−3) : [(−2) + (−1)] = ***

# %% [markdown]
# **028 Calcula.**
#
# a) (3 + 2) ⋅ (3 − 1 + 4) − 2 ⋅ (2 ⋅ 3) = **
#
# b) [(15 − 16 + 2) ⋅ (−1) + 9] ⋅ 7 = **
#
# c) 2 ⋅ [−2 − 2 − (2 − 2 − 2)] = **
#
# d) [2 + 3 − (6 + 5)] − [(4 ⋅ 2) ⋅ (−3 ⋅ 6) + 1] = **

# %% [markdown]
# **029 Completa los huecos para que se cumplan las igualdades.**
#
# a) (−6) ⋅ [(−1) + **] = −18
#
# b) 8 ⋅ [4 − **] = 32
#
# c) 3 − [** ⋅ 5] = 18
#
# d) 1 + [3 : **] = −2

# %% [markdown]
# **030 Expresa mediante una razón.**
#
# a) De las 55 preguntas del test he acertado 36.
#
# b) Teníamos 68 huevos y se han roto 12.
#
# c) En el primer turno de comida comen 94 alumnos, y en el segundo, 65.
#
# d) Una frutería tiene 7 cajas de tomates y 3 de pimientos.
#
# **SOlución**
#     a).-
#     b).-
#     c).-
#     d).-

# %% [markdown]
# **31 En el comedor del colegio ponen 3 barras de pan por cada 8 alumnos.
# Hoy hemos comido 124 alumnos y han puesto 50 barras, ¿se ha mantenido
# la proporción?**

# %% [markdown]
# <font color = "blue">**Razón** es el cociente entre dos números a y b. Una razón no tiene unidades y sirve para comparar: indica el nº de veces que una cantidad es mayor que otra.
#
# Ejemplo: La razón entre 10 y 2 es $\frac {10}{2} = 5$</font>

# %% [markdown]
# **032 Identifica las razones que forman una proporción.
#
#     a).- $\frac{2}{1},$\frac{8}{2},$\frac{6}{3},$\frac{9}{5}$
#
#     b).- $\frac{10}{2},$\frac{50}{10},$\frac{30}{8},$\frac{20}{5}$
#
#     c).- $\frac{7,5}{3},$\frac{4}{6},$\frac{3}{2},$\frac{10}{4}$
#
# **Solución**
#
#     a).- Forman proporción:
#
#     b).- Forman proporción:
#
#     c).- Forman proporción:

# %% [markdown]
# **033 Tuilla: SOLO EL 8 % DE LOS ENCUESTADOS CRITICA LA LABOR MUNICIPAL.»
# Si Tuilla tiene 7.000 habitantes, ¿cuántos, aproximadamente,
# aprueban la labor del alcalde?

# %% [markdown]
# **034 La composición de un yogur es: Proteinas, 3,5%; Carbohidratos, 13,4% y Frasas, 1,9%. Calcula el peso de sus componentes si pesa 125 g.**

# %% [markdown]
# ## Geometría

# %% [markdown]
# **035 Dibuja un polígono de cinco lados en tu cuaderno y señala sus lados, vértices y ángulos. Traza sus diagonales. ¿Cuántas diagonales tiene?**

# %% [markdown]
# <font color = "blue">Un **eneágono o nonágono** es un polígono de nueve lados y nueve vértices.</font>
#
# <font color = "blue">Se denomina **decágono** a un polígono de diez lados y diez vértices</font>

# %% [markdown]
# **036 Dibuja un octógono, un eneágono y un decágono que no sean regulares
# y dibuja sus diagonales.**

# %% [markdown]
# **037 Contesta si es verdadero o falso.**
#
# a) Un polígono puede tener más vértices que lados.
#
# b) Un polígono puede tener más vértices que ángulos.
#
# c) Un polígono puede tener más vértices que diagonales.

# %% [markdown]
# **038 Dibuja una circunferencia con un compás. Después, traza una cuerda
# y los dos arcos que determina.**

# %% [markdown]
# **039 En una circunferencia, traza una cuerda, un radios y un diámetros.

# %% [markdown]
# **040 Contesta a estas preguntas.**
#
# a) Un triángulo rectángulo, ¿puede ser equilátero?
#
# b) ¿Cuál es el valor de los ángulos de un triángulo rectángulo isósceles?
#
# c) ¿Cuánto miden los ángulos de un triángulo rectángulo con un ángulo agudo que mide el triple que el otro ángulo agudo?

# %% [markdown]
# **041 Un triángulo isósceles tiene el ángulo desigual de 50°. ¿Cuánto miden
# los ángulos iguales?**

# %% [markdown]
# **042 Si dibujamos un triángulo rectángulo, uno isósceles y otro escaleno,
# y los cortamos por una recta paralela a la base, ¿qué polígonos obtenemos
# en cada caso?**

# %% [markdown]
# **043 Calcula la medida de C$ en este trapecio rectángulo sabiendo que B$ = 45°.**
#
#  ![043_Repaso.JPG](attachment:043_Repaso.JPG)

# %% [markdown]
# ## Funciones

# %% [markdown]
# **044 Indica las coordenadas de cada punto.
#
# ![044_Repaso.JPG](attachment:044_Repaso.JPG)

# %% [markdown]
# **045 Dados los siguientes puntos: A(4, −1), B(3, 4), C(−3, 2) y D(−2, −3):**
#
# a) Represéntalos en el plano.
#
# b) Únelos en orden alfabético y une también D con A. ¿Qué figura obtienes?

# %% [markdown]
# **046 Haz lo mismo con estos puntos: A(5, 0), B(3, 4), C(−3, 4), D(−5, 0) y E(0, −4).**

# %% [markdown]
# **047 Representa los siguientes puntos: A(−5, 2), B(4, 0), C(−5, −1), D(8, 2) y E(−1, 2).**
#
# a) Indica los puntos que tienen la misma ordenada.
#
# b) ¿Cuántos puntos tienen la misma abscisa? ¿Cuáles son?

# %% [markdown]
# **048 Dibuja los ejes de coordenadas para que el punto sea A(2, −1).**

# %% [markdown]
# Adaptado de : [EJERCICIOS libro ed. Santillana 3º ESO ](https://www.alfonsogonzalez.es/asignaturas/3_eso/ejercicios_3_eso_resueltos.html)
#
# http://jlmat.es/index.php/mnu-3eso/9-apuntes-3-eso.html

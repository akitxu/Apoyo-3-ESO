# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Potencias" data-toc-modified-id="Potencias-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Potencias</a></span></li><li><span><a href="#Radicales" data-toc-modified-id="Radicales-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Radicales</a></span><ul class="toc-item"><li><span><a href="#Factores-en-radicales.-Extraer-factores" data-toc-modified-id="Factores-en-radicales.-Extraer-factores-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Factores en radicales. Extraer factores</a></span></li><li><span><a href="#Factores-fuera-del-radical.-Introducir-factores" data-toc-modified-id="Factores-fuera-del-radical.-Introducir-factores-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Factores fuera del radical. Introducir factores</a></span></li><li><span><a href="#Igualación-de-indices." data-toc-modified-id="Igualación-de-indices.-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Igualación de indices.</a></span></li><li><span><a href="#Suma-de-radicales" data-toc-modified-id="Suma-de-radicales-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Suma de radicales</a></span></li><li><span><a href="#Conversión-de-índices-y-suma-de-radicales" data-toc-modified-id="Conversión-de-índices-y-suma-de-radicales-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Conversión de índices y suma de radicales</a></span></li><li><span><a href="#Sumas-con-radicales-como-denominadores" data-toc-modified-id="Sumas-con-radicales-como-denominadores-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Sumas con radicales como denominadores</a></span></li><li><span><a href="#Productos-de-radicales" data-toc-modified-id="Productos-de-radicales-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Productos de radicales</a></span></li><li><span><a href="#Divisiones-con-radicales" data-toc-modified-id="Divisiones-con-radicales-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Divisiones con radicales</a></span></li><li><span><a href="#Simplificar" data-toc-modified-id="Simplificar-2.9"><span class="toc-item-num">2.9&nbsp;&nbsp;</span>Simplificar</a></span></li><li><span><a href="#Jerarquía-al-resilver-radicales" data-toc-modified-id="Jerarquía-al-resilver-radicales-2.10"><span class="toc-item-num">2.10&nbsp;&nbsp;</span>Jerarquía al resilver radicales</a></span></li><li><span><a href="#Potencias-de-un-radical" data-toc-modified-id="Potencias-de-un-radical-2.11"><span class="toc-item-num">2.11&nbsp;&nbsp;</span>Potencias de un radical</a></span></li><li><span><a href="#Binomios-y-radicales" data-toc-modified-id="Binomios-y-radicales-2.12"><span class="toc-item-num">2.12&nbsp;&nbsp;</span>Binomios y radicales</a></span></li><li><span><a href="#Operaciones-mixtas-con-radicales" data-toc-modified-id="Operaciones-mixtas-con-radicales-2.13"><span class="toc-item-num">2.13&nbsp;&nbsp;</span>Operaciones mixtas con radicales</a></span></li><li><span><a href="#Raices-de-raices" data-toc-modified-id="Raices-de-raices-2.14"><span class="toc-item-num">2.14&nbsp;&nbsp;</span>Raices de raices</a></span></li><li><span><a href="#Racionalizar-radicales" data-toc-modified-id="Racionalizar-radicales-2.15"><span class="toc-item-num">2.15&nbsp;&nbsp;</span>Racionalizar radicales</a></span></li><li><span><a href="#Leyes-de-potencias-en-radicales" data-toc-modified-id="Leyes-de-potencias-en-radicales-2.16"><span class="toc-item-num">2.16&nbsp;&nbsp;</span>Leyes de potencias en radicales</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Potencias y radicales
# [superprofe](https://www.superprof.es/apuntes/escolar/matematicas/aritmetica/reales/radicales-2.html#tema_potencias-racionales)
#
# [Exámenes de matemáticas](https://lasmatematicas.eu/docs/eso/3eso/examenes/15-notacion-cientifica-radicales-1.pdf)

# %% [markdown]
# ## Potencias

# %% [markdown]
# ## Radicales

# %% [markdown]
# ### Factores en radicales. Extraer factores

# %% [markdown]
# 1.- $ \sqrt{2 \cdot 3² \cdot 5⁵}$
#
# 2.- $ \sqrt[4]{2⁷ \cdot 3^{14} \cdot 5⁴}$

# %% [markdown]
# ### Factores fuera del radical. Introducir factores

# %% [markdown]
# 1) $\qquad 2 \sqrt{3}$
#
# 2) $\qquad 2² \cdot 3³ \cdot \sqrt[4]{6}$

# %% [markdown]
# ### Igualación de indices.
# Poner un índice común

# %% [markdown]
# 1) $\quad \sqrt{2} \qquad$ $\quad \sqrt [3]{2^2  \cdot 3^2} \qquad$ $\qquad \sqrt [4]{2^2 \cdot 3^3}$
#
# 2)

# %% [markdown]
# ### Suma de radicales

# %% [markdown]
# a) $\qquad 2 \sqrt{2} - 4 \sqrt{2}+ \sqrt {2}$
#
# b) $\qquad 3 \sqrt[4]{5} - 2 \sqrt[4]{5 }- \sqrt[4]{5}$
#
# c) $\qquad \sqrt{12} - 3\sqrt{3} + 2 \sqrt{75}$
#
# d) $\qquad \sqrt[4]{4} + \sqrt[6]{8} - \sqrt[12]{64}$

# %% [markdown]
# ### Conversión de índices y suma de radicales

# %% [markdown]
#  a) $\qquad 2 \sqrt{12}-3\sqrt{75}+\sqrt{27}$
#
#  b) $\qquad \sqrt{24}-5\sqrt{6}+\sqrt{486}$
#
#  c) $\qquad 2\sqrt{5}+\sqrt{45}+\sqrt{180}-\sqrt{80}$
#
#  d) $\qquad \sqrt[3]{53}-\sqrt[3]{16}+\sqrt[3]{250}$

# %% [markdown]
# ### Sumas con radicales como denominadores

# %% [markdown]
# a) $\qquad \sqrt{2}+ \frac{1}{\sqrt{2}}$
#
# b) $\qquad \sqrt[3]{16}+\sqrt[3]{250}+\sqrt[6]{4}- \frac{1}{\sqrt[3]{4}}$

# %% [markdown]
# ### Productos de radicales

# %% [markdown]
# a) $\qquad \sqrt{2}\cdot\sqrt{6}$
#
# b) $\qquad \sqrt{3} \cdot \sqrt[3]{9} \cdot [4]{27}$
#
# c) $\qquad \sqrt{12} \cdot \sqrt[3]{36}$

# %% [markdown]
# ### Divisiones con radicales

# %% [markdown]
# a) $\qquad \frac{\sqrt[6]{128}}{\sqrt[6]{16}}$
#
# b) $\qquad \frac{\sqrt[3]{4}}{\sqrt{2}}$
#
# c) $\qquad \frac{\sqrt{256}}{\sqrt[3]{16}}$

# %% [markdown]
# ### Simplificar

# %% [markdown]
# $\qquad \frac{\sqrt{a} \cdot \sqrt[3]{a^2} \cdot \sqrt[4]{a^3}}{\sqrt[6]{a^4}}$

# %% [markdown]
# ### Jerarquía al resilver radicales

# %% [markdown]
# $\qquad \sqrt[4] \frac {\sqrt[3]{2} }{\sqrt{\frac{1}{8}}}$

# %% [markdown]
# ### Potencias de un radical

# %% [markdown]
# a) $\qquad \sqrt[3]{18}^2$
#
# b) $\qquad \left (\frac{\sqrt[3]{12} \cdot \sqrt[4]{18}}{\sqrt{6}} \right )^4$

# %% [markdown]
# ### Binomios y radicales

# %% [markdown]
# a) $\qquad \left (\sqrt{7} - \sqrt{2}  \right )^2$
#
# b) $\qquad \left ( 2 - \sqrt{3} \right )^2$
#
# c) $\qquad \left ( \sqrt{5} + 2 \right ) \left ( \sqrt{5} - 2 \right )$
#
# d) $\qquad \left (2 \sqrt{5} + 3 \sqrt{2} \right ) \left (2 \sqrt{5} - 3 \sqrt{2} \right ) $

# %% [markdown]
# ### Operaciones mixtas con radicales

# %% [markdown]
# a) $\qquad \frac{1}{2-\sqrt{3}} \cdot \frac{1}{2+\sqrt{3}}$
#
# b) $  \sqrt{ \frac{a-b}{(a-b)^2} \cdot \frac{a+b}{a^2-b²}} $

# %% [markdown]
# ### Raices de raices

# %% [markdown]
# a) $\qquad \sqrt{\sqrt[3]{\sqrt[4]{2}}    }$
#
# a) $\qquad \sqrt{2 \sqrt[3]{2\sqrt[4]{2}}    }$
#
# a) $\qquad \sqrt{\sqrt[3]{ \sqrt{    \sqrt[3]{ 2 \sqrt{2}} } } }$

# %% [markdown]
# ### Racionalizar radicales

# %% [markdown]
# <font color = "green">
# **Ejemplo**
#
# $\frac{2}{3 \sqrt{2}} =  \frac {2\sqrt{2}}{3 \sqrt{2} \sqrt{2}}=$
#
# $=  \frac{2\sqrt{2}}{3(\sqrt{2})^2} =$
#
# $= \frac{2 \sqrt{2}}{3 \cdot 2} =$
#
# $= \frac{2 \sqrt{2}}{3 }  $
#
# </font>

# %% [markdown]
#  a) $\qquad \frac{2}{ 3 \sqrt[5]{4}}$
#
#  b) $\qquad \frac{2}{\sqrt{2} - \sqrt{3}}$
#
#  c) $\qquad \frac{2}{ 4 - 2 \sqrt{2}}$
#
#  d) $\qquad \frac{2 \sqrt{2}}{5 - 2 \sqrt{6}}$

# %% [markdown]
# ### Leyes de potencias en radicales

# %% [markdown]
# a) $\qquad \frac{5}{2 \quad{2}}$
#
# b) $\qquad \frac{1}{\sqrt[3]{3}}$
#
# c) $\qquad \frac{2}{3 + \sqrt{3}}$
#
# d) $\qquad \frac{\sqrt{2}}{\sqrt{3} - \sqrt{2}}$
#
# e) $\qquad \frac{3 \sqrt{2} - 2 \sqrt{3}}{3 \sqrt{2} + 2 \sqrt{3}}

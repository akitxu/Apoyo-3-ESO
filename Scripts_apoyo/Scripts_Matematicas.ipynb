# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Teorema-de-pitágoras" data-toc-modified-id="Teorema-de-pitágoras-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Teorema de pitágoras</a></span></li><li><span><a href="#Descomponer-en-factores-primos" data-toc-modified-id="Descomponer-en-factores-primos-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Descomponer en factores primos</a></span><ul class="toc-item"><li><span><a href="#http://iterando.online/ejercicios-resueltos/descomposicion-en-factores-primos-en-python/" data-toc-modified-id="http://iterando.online/ejercicios-resueltos/descomposicion-en-factores-primos-en-python/-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span><a href="http://iterando.online/ejercicios-resueltos/descomposicion-en-factores-primos-en-python/" target="_blank">http://iterando.online/ejercicios-resueltos/descomposicion-en-factores-primos-en-python/</a></a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Teorema de pitágoras

# %%
import math
a = 3
b = 4

h = math.sqrt(a**2 + b**2)
h
# Out:
# 5.0

# %% [markdown]
# ## Descomponer en factores primos

# %% [markdown]
# ### http://iterando.online/ejercicios-resueltos/descomposicion-en-factores-primos-en-python/

# %%
def descomponer_factores(n):
    productoria = 1
    copia_n = n
    factor_primo = 2
    cant_factores = 0
    hay_factores = False
    while True:
        resto = copia_n % factor_primo
        if resto == 0:            
            copia_n //= factor_primo
            productoria *= factor_primo
            cant_factores += 1
        else:  
            if cant_factores > 0:
                if hay_factores:
                    print("x", end="")
                else:
                    hay_factores = True
                if cant_factores==1:
                    print(factor_primo, end="")
                else:
                    print("{:d}^{:d}".format(factor_primo, cant_factores), end="")
                cant_factores = 0
            factor_primo = siguiente_primo(factor_primo)
        
        if productoria == n:
            break
    if hay_factores:
        print("x", end="")
    if cant_factores==1:
        print(factor_primo, end="")
    else:
        print("{:d}^{:d}".format(factor_primo, cant_factores), end="") 
        
descomponer_factores(564)
